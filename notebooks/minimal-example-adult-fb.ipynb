# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
complete_data = pd.read_csv('../resources/data/adult/adult.csv')

# %% [markdown]
# ### Load dataset, resample to have balanced classes

# %%
rich = complete_data[complete_data['class'] == '>50K']
not_rich = complete_data[complete_data['class'] != '>50K'].sample(len(rich))

data = pd.concat([rich, not_rich])

# %%
data
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 14      40           Private  121772     Assoc-voc             11
# 19      43  Self-emp-not-inc  292175       Masters             14
# 20      40           Private  193524     Doctorate             16
# 25      56         Local-gov  216851     Bachelors             13
# 27      54                 ?  180211  Some-college             10
# 38      31           Private   84154  Some-college             10
# 45      57       Federal-gov  337895     Bachelors             13
# 52      47           Private   51835   Prof-school             15
# 53      50       Federal-gov  251585     Bachelors             13
# 55      43           Private  237993  Some-college             10
# 63      42           Private  116632     Doctorate             16
# 67      53           Private  169846       HS-grad              9
# 68      49      Self-emp-inc  191681  Some-college             10
# 72      29  Self-emp-not-inc  162298     Bachelors             13
# 84      44           Private  343591       HS-grad              9
# 86      49         Local-gov  268234       HS-grad              9
# 89      43       Federal-gov  410867     Doctorate             16
# 94      34         Local-gov  226296     Bachelors             13
# 96      48  Self-emp-not-inc  191277     Doctorate             16
# 97      37           Private  202683  Some-college             10
# 100     76           Private  124191       Masters             14
# 101     44           Private  198282     Bachelors             13
# 105     32      Self-emp-inc  317660       HS-grad              9
# 111     38           Private   65324   Prof-school             15
# 112     56  Self-emp-not-inc  335605       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 34      22         State-gov  311512  Some-college             10
# 19608   33           Private  213002     Bachelors             13
# 14280   21                 ?  145964  Some-college             10
# 14293   53       Federal-gov   39643       HS-grad              9
# 30442   22           Private  232985       HS-grad              9
# 656     70                 ?  167358           9th              5
# 10348   26           Private  190330     Bachelors             13
# 9545    50           Private  209464       HS-grad              9
# 25687   70           Private  195739          10th              6
# 16179   19                 ?  119234  Some-college             10
# 8712    40           Private  187164       HS-grad              9
# 18166   33         Local-gov  289716          10th              6
# 11012   45           Private  190115    Assoc-acdm             12
# 8159    27         Local-gov   74056     Bachelors             13
# 21958   43           Private  117915       Masters             14
# 29667   58           Private  407138       7th-8th              4
# 18460   29           Private  250819  Some-college             10
# 7933    40           Private  136244  Some-college             10
# 10234   27           Private  192283     Assoc-voc             11
# 12974   40           Private  167919       HS-grad              9
# 32340   75  Self-emp-not-inc  192813       Masters             14
# 31407   24           Private  493034     Bachelors             13
# 4849    47  Self-emp-not-inc   83064     Bachelors             13
# 19790   55           Private  141877     Bachelors             13
# 2225    23         State-gov  235853     Bachelors             13
# 8110    41           Private  202980       HS-grad              9
# 23406   35           Private  220595       HS-grad              9
# 31571   48           Private  185079       HS-grad              9
# 30528   44           Private  223194       HS-grad              9
# 30741   62           Private  214288       HS-grad              9
#
#            marital_status         occupation    relationship  \
# 7      Married-civ-spouse    Exec-managerial         Husband
# 8           Never-married     Prof-specialty   Not-in-family
# 9      Married-civ-spouse    Exec-managerial         Husband
# 10     Married-civ-spouse    Exec-managerial         Husband
# 11     Married-civ-spouse     Prof-specialty         Husband
# 14     Married-civ-spouse       Craft-repair         Husband
# 19               Divorced    Exec-managerial       Unmarried
# 20     Married-civ-spouse     Prof-specialty         Husband
# 25     Married-civ-spouse       Tech-support         Husband
# 27     Married-civ-spouse                  ?         Husband
# 38     Married-civ-spouse              Sales         Husband
# 45     Married-civ-spouse     Prof-specialty         Husband
# 52     Married-civ-spouse     Prof-specialty            Wife
# 53               Divorced    Exec-managerial   Not-in-family
# 55     Married-civ-spouse       Tech-support         Husband
# 63     Married-civ-spouse     Prof-specialty         Husband
# 67     Married-civ-spouse       Adm-clerical            Wife
# 68     Married-civ-spouse    Exec-managerial         Husband
# 72     Married-civ-spouse              Sales         Husband
# 84               Divorced       Craft-repair   Not-in-family
# 86     Married-civ-spouse    Protective-serv         Husband
# 89          Never-married     Prof-specialty   Not-in-family
# 94     Married-civ-spouse    Protective-serv         Husband
# 96     Married-civ-spouse     Prof-specialty         Husband
# 97     Married-civ-spouse              Sales         Husband
# 100    Married-civ-spouse    Exec-managerial         Husband
# 101    Married-civ-spouse    Exec-managerial         Husband
# 105    Married-civ-spouse       Craft-repair         Husband
# 111    Married-civ-spouse     Prof-specialty         Husband
# 112    Married-civ-spouse      Other-service         Husband
# ...                   ...                ...             ...
# 34     Married-civ-spouse      Other-service         Husband
# 19608       Never-married     Prof-specialty   Not-in-family
# 14280       Never-married                  ?       Own-child
# 14293             Widowed    Exec-managerial   Not-in-family
# 30442       Never-married  Handlers-cleaners  Other-relative
# 656               Widowed                  ?       Unmarried
# 10348       Never-married      Other-service   Not-in-family
# 9545            Separated      Other-service       Unmarried
# 25687             Widowed       Craft-repair       Unmarried
# 16179       Never-married                  ?  Other-relative
# 8712   Married-civ-spouse    Exec-managerial         Husband
# 18166  Married-civ-spouse   Transport-moving         Husband
# 11012            Divorced    Exec-managerial       Unmarried
# 8159        Never-married       Tech-support   Not-in-family
# 21958       Never-married       Adm-clerical   Not-in-family
# 29667  Married-civ-spouse  Machine-op-inspct         Husband
# 18460       Never-married       Adm-clerical   Not-in-family
# 7933   Married-civ-spouse       Adm-clerical            Wife
# 10234       Never-married  Handlers-cleaners       Own-child
# 12974  Married-civ-spouse       Craft-repair         Husband
# 32340             Widowed              Sales   Not-in-family
# 31407       Never-married     Prof-specialty   Not-in-family
# 4849   Married-civ-spouse    Farming-fishing         Husband
# 19790  Married-civ-spouse  Machine-op-inspct         Husband
# 2225        Never-married       Tech-support   Not-in-family
# 8110   Married-civ-spouse       Craft-repair         Husband
# 23406  Married-civ-spouse       Craft-repair         Husband
# 31571       Never-married    Exec-managerial   Not-in-family
# 30528  Married-civ-spouse       Craft-repair         Husband
# 30741  Married-civ-spouse  Machine-op-inspct         Husband
#
#                      race     sex  capital_gain  capital_loss  hours_per_week  \
# 7                   White    Male             0             0              45
# 8                   White  Female         14084             0              50
# 9                   White    Male          5178             0              40
# 10                  Black    Male             0             0              80
# 11     Asian-Pac-Islander    Male             0             0              40
# 14     Asian-Pac-Islander    Male             0             0              40
# 19                  White  Female             0             0              45
# 20                  White    Male             0             0              60
# 25                  White    Male             0             0              40
# 27     Asian-Pac-Islander    Male             0             0              60
# 38                  White    Male             0             0              38
# 45                  Black    Male             0             0              40
# 52                  White  Female             0          1902              60
# 53                  White    Male             0             0              55
# 55                  White    Male             0             0              40
# 63                  White    Male             0             0              45
# 67                  White  Female             0             0              40
# 68                  White    Male             0             0              50
# 72                  White    Male             0             0              70
# 84                  White  Female         14344             0              40
# 86                  White    Male             0             0              40
# 89                  White  Female             0             0              50
# 94                  White    Male             0             0              40
# 96                  White    Male             0          1902              60
# 97                  White    Male             0             0              48
# 100                 White    Male             0             0              40
# 101                 White    Male         15024             0              60
# 105                 White    Male          7688             0              40
# 111                 White    Male             0             0              40
# 112                 White    Male             0          1887              50
# ...                   ...     ...           ...           ...             ...
# 34                  Black    Male             0             0              15
# 19608               White    Male             0          1408              36
# 14280               White    Male             0             0              40
# 14293               White  Female             0             0              58
# 30442               White    Male             0             0              20
# 656                 White  Female          1111             0              15
# 10348               White    Male             0             0              30
# 9545                White  Female             0             0              35
# 25687               White    Male             0             0              45
# 16179               White  Female             0             0              15
# 8712                White    Male             0          1672              45
# 18166               White    Male             0             0              40
# 11012               White    Male             0             0              40
# 8159                White    Male             0             0              50
# 21958               White    Male             0             0              40
# 29667               White    Male          2936             0              50
# 18460               White  Female             0             0              40
# 7933                White  Female             0             0              40
# 10234               White  Female             0             0              38
# 12974               White    Male             0             0              40
# 32340               White    Male             0             0              45
# 31407               Black    Male             0             0              40
# 4849                White    Male             0             0              60
# 19790               White    Male             0             0              40
# 2225                White    Male             0             0              22
# 8110                White    Male             0             0               4
# 23406               White    Male             0             0              40
# 31571               White  Female             0             0              50
# 30528               Black    Male             0          1485              40
# 30741               White    Male             0             0              40
#
#       native_country  class
# 7      United-States   >50K
# 8      United-States   >50K
# 9      United-States   >50K
# 10     United-States   >50K
# 11             India   >50K
# 14                 ?   >50K
# 19     United-States   >50K
# 20     United-States   >50K
# 25     United-States   >50K
# 27             South   >50K
# 38                 ?   >50K
# 45     United-States   >50K
# 52          Honduras   >50K
# 53     United-States   >50K
# 55     United-States   >50K
# 63     United-States   >50K
# 67     United-States   >50K
# 68     United-States   >50K
# 72     United-States   >50K
# 84     United-States   >50K
# 86     United-States   >50K
# 89     United-States   >50K
# 94     United-States   >50K
# 96     United-States   >50K
# 97     United-States   >50K
# 100    United-States   >50K
# 101    United-States   >50K
# 105    United-States   >50K
# 111    United-States   >50K
# 112           Canada   >50K
# ...              ...    ...
# 34     United-States  <=50K
# 19608  United-States  <=50K
# 14280  United-States  <=50K
# 14293  United-States  <=50K
# 30442  United-States  <=50K
# 656    United-States  <=50K
# 10348  United-States  <=50K
# 9545   United-States  <=50K
# 25687  United-States  <=50K
# 16179  United-States  <=50K
# 8712   United-States  <=50K
# 18166  United-States  <=50K
# 11012  United-States  <=50K
# 8159   United-States  <=50K
# 21958  United-States  <=50K
# 29667         Mexico  <=50K
# 18460  United-States  <=50K
# 7933   United-States  <=50K
# 10234  United-States  <=50K
# 12974  United-States  <=50K
# 32340  United-States  <=50K
# 31407  United-States  <=50K
# 4849   United-States  <=50K
# 19790  United-States  <=50K
# 2225   United-States  <=50K
# 8110            Peru  <=50K
# 23406  United-States  <=50K
# 31571  United-States  <=50K
# 30528          Haiti  <=50K
# 30741  United-States  <=50K
#
# [15682 rows x 15 columns]

# %%
data['occupation'].value_counts()
# ['workclass', 'occupation', 'marital_status', 'education']].value_counts()
# Out:
# Exec-managerial      2626
# Prof-specialty       2555
# Craft-repair         1929
# Sales                1821
# Adm-clerical         1537
# Other-service        1116
# Machine-op-inspct     854
# Transport-moving      732
# ?                     729
# Tech-support          500
# Handlers-cleaners     489
# Farming-fishing       390
# Protective-serv       361
# Priv-house-serv        40
# Armed-Forces            3
# Name: occupation, dtype: int64

# %% [markdown]
# ### Train a logistic regression model, using grid search and k-fold cross-validation

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings('ignore')

def labels_from(df):
    return np.array(df['class'] == '>50K')

train_data, heldout_data = train_test_split(data, test_size=0.2)
test_data, target_data = train_test_split(heldout_data, test_size=0.5)

y_train = labels_from(train_data)
y_test = labels_from(test_data)
y_target = labels_from(target_data)

categorical_columns = ['workclass', 'occupation', 'marital_status', 'education']

numeric_columns = ['hours_per_week', 'age']

feature_transformation = ColumnTransformer(transformers=[
    ('categorical_features', OneHotEncoder(handle_unknown='ignore'), categorical_columns),
    ('scaled_numeric', StandardScaler(), numeric_columns)
])

param_grid = {
    'learner__loss': ['log'],
    'learner__penalty': ['l2', 'l1', 'elasticnet'],
    'learner__alpha': [0.0001, 0.001, 0.01, 0.1]
}

pipeline = Pipeline([
    ('features', feature_transformation), 
    ('learner', SGDClassifier(max_iter=1000))])

search = GridSearchCV(pipeline, param_grid, cv=5)
model = search.fit(train_data, y_train)

# %%
score_on_train_data = accuracy_score(y_train, model.predict(train_data))
score_on_noncorrupted_test_data = accuracy_score(y_test, model.predict(test_data))
score_on_noncorrupted_target_data = accuracy_score(y_target, model.predict(target_data))

print("score on train data: ", score_on_train_data)
print("score on test data: ", score_on_noncorrupted_test_data)
print("score on target data: ", score_on_noncorrupted_target_data)
# Out:
# score on train data:  0.8097249900358708
# score on test data:  0.7927295918367347
# score on target data:  0.7884002549394519

# %% [markdown]
# ### Introduce errors (missing values) into unseen test data, record resulting class probability entropies and accuracy score as inputs for the meta regressor

# %%
import random
from scipy.stats import entropy
from tqdm import tqdm

def delete_cells(df, fraction, columns):
    # we operate on a copy of the data
    corrupted_df = df.copy(deep=True)
    
    row_indexes = [row for row in range(corrupted_df.shape[0])]
    # pick random examples
    num_rows_to_pick = int(round(fraction * len(row_indexes)))
    for random_row_index in random.sample(row_indexes, num_rows_to_pick):           
        # delete all specified values in the target columns
        for column in columns:
            column_index = df.columns.get_loc(column)
            corrupted_df.iat[random_row_index, column_index] = 'n/a'
    
    return corrupted_df

def delete_groups(df, fraction, columns):
    # we operate on a copy of the data
    corrupted_df = df.copy(deep=True)
    
    # for each group remove a given fraction of groups
    # groups to discard are sampled with a probability 
    # proportional to their frequency
    for col in columns:
        groups = df[col].value_counts()
        n_groups = int(len(groups) * fraction)
        groups_to_delete = np.random.choice(groups.index,
                                           n_groups,
                                           p=groups/groups.sum(),
                                           replace=False)
        corrupted_df.loc[corrupted_df[col].isin(groups_to_delete), col] = 'n/a'
    
    return corrupted_df

def compute_meta_features(predictions):
    entropy_good = entropy(np.transpose(predictions)[0])
    entropy_bad = entropy(np.transpose(predictions)[1])
    entropy_predictions = entropy((predictions * np.log(predictions)).sum(axis=1))
    #tammo = np.mean([np.max(prediction) for prediction in predictions])
    return [entropy_good, entropy_bad, entropy_predictions]


generated_training_data = []
          
# Sebastian's perturbations (missing values, at random)
for num_columns_affected in tqdm(range(1, 5)):
    for fraction_of_groups_to_delete in [0.0, 0.05, 0.25, 0.5, 0.75, 0.99]:    
        for _ in range(0, 100):             
            columns_affected = np.random.choice(categorical_columns, num_columns_affected)        
            corrupted_test_data = delete_groups(test_data, fraction_of_values_to_delete, columns_affected)
            predictions = model.predict_proba(corrupted_test_data)
            score_on_corrupted_test_data = accuracy_score(y_test, model.predict(corrupted_test_data))  
            meta_features_and_scores = compute_meta_features(predictions) + [score_on_corrupted_test_data]
            generated_training_data.append(meta_features_and_scores)
            
# And additionally, Felix' perturbations (missing groups of categorical features)
for num_columns_affected in tqdm(range(1, 5)):
    for fraction_of_values_to_delete in [0.0, 0.05, 0.25, 0.5, 0.75, 0.99]:    
        for _ in range(0, 100):        
            
            columns_affected = np.random.choice(categorical_columns, num_columns_affected)        
            corrupted_test_data = delete_cells(test_data, fraction_of_values_to_delete, columns_affected)
            predictions = model.predict_proba(corrupted_test_data)
            score_on_corrupted_test_data = accuracy_score(y_test, model.predict(corrupted_test_data))  
            meta_features_and_scores = compute_meta_features(predictions) + [score_on_corrupted_test_data]
            generated_training_data.append(meta_features_and_scores)
# Out:
# 100%|██████████| 4/4 [00:19<00:00,  4.85s/it]
# 100%|██████████| 4/4 [00:56<00:00, 14.12s/it]

# %% [markdown]
# ### Plot relation between entropy of predicted class probabilities and accuracy

# %%
entropies_good = np.transpose(generated_training_data)[0]
entropies_bad = np.transpose(generated_training_data)[1]
entropies_predictions = np.transpose(generated_training_data)[2]
accuracies = np.transpose(generated_training_data)[3]

plt.scatter(entropies_good, accuracies)
plt.scatter(entropies_bad, accuracies)
plt.scatter(entropies_predictions, accuracies)
plt.xlabel("entropy of class probabilities")
plt.ylabel("accuracy")
plt.legend(['good','bad','entropy'])
plt.show()

# %% [markdown]
# ### Evaluate regression model in predicting effects of errors in the unseen target data

# %%
generated_target_data = []

# Sebastian's perturbations (missing values, at random)
for num_columns_affected in tqdm(range(1, 5)):
    for fraction_of_values_to_delete in [0.05, 0.25, 0.5, 0.75, 0.99]:    
        for _ in range(0, 100):        
            columns_affected = np.random.choice(categorical_columns, num_columns_affected)        

            corrupted_target_data = delete_cells(target_data, fraction_of_values_to_delete, columns_affected)
            predictions = model.predict_proba(corrupted_target_data)
            score_on_corrupted_target_data = accuracy_score(y_target, model.predict(corrupted_target_data))  
            meta_features_and_scores = compute_meta_features(predictions) + [score_on_corrupted_target_data]
            generated_target_data.append(meta_features_and_scores)

# And additionally, Felix' perturbations (missing groups of categorical features)
for num_columns_affected in tqdm(range(1, 5)):
    for fraction_of_groups_to_delete in [0.05, 0.25, 0.5, 0.75, 0.99]:    
        for _ in range(0, 100):        
            columns_affected = np.random.choice(categorical_columns, num_columns_affected)        

            corrupted_target_data = delete_groups(target_data, fraction_of_groups_to_delete, columns_affected)
            
            predictions = model.predict_proba(corrupted_target_data)
            score_on_corrupted_target_data = accuracy_score(y_target, model.predict(corrupted_target_data))  
            meta_features_and_scores = compute_meta_features(predictions) + [score_on_corrupted_target_data]
            generated_target_data.append(meta_features_and_scores)
# Out:
# 100%|██████████| 4/4 [00:52<00:00, 13.05s/it]
# 100%|██████████| 4/4 [00:34<00:00,  8.63s/it]

# %% [markdown]
# ### Fit a simple regression model to the generated training data

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor

X = np.array(generated_training_data)[:,:2]
y = np.array(generated_training_data)[:,3]

param_grid = {
    'learner__n_neighbors': list(range(1,10))
}

meta_regressor_pipeline = Pipeline([
    ('scaling', StandardScaler()), 
    ('learner', KNeighborsRegressor())
])


meta_regressor = GridSearchCV(meta_regressor_pipeline, param_grid).fit(X, y)
true_scores = np.vstack(generated_target_data)[:,-1]
predicted_scores_knn = meta_regressor.predict(np.vstack(generated_target_data)[:,:2])

# %%
meta_regressor_pipeline = Pipeline([
    ('scaling', StandardScaler()), 
    ('learner', LinearRegression())
])


meta_regressor = meta_regressor_pipeline.fit(X, y)
true_scores = np.vstack(generated_target_data)[:,-1]
predicted_scores_lr = meta_regressor.predict(np.vstack(generated_target_data)[:,:2])

from scipy import stats

gradient_knn, intercept_knn, _, _, _ = stats.linregress(np.array(true_scores).flatten(), np.array(predicted_scores_knn).flatten())

plt.scatter(true_scores, predicted_scores_knn, alpha=0.05)

x1 = np.linspace(0.6, 0.8, 100)
plt.plot(x1, gradient_knn * x1 + intercept_knn, '-')

gradient_lr, intercept_lr, _, _, _ = stats.linregress(np.array(true_scores).flatten(), np.array(predicted_scores_lr).flatten())

plt.scatter(true_scores, predicted_scores_lr, alpha=0.05)

x1 = np.linspace(0.6, 0.8, 100)
plt.plot(x1, gradient_lr * x1 + intercept_lr, '-')

plt.xlabel("true accuracy on corrupted target data")
plt.ylabel("predicted accuracy on corrupted target data")
plt.plot([0.6, 0.8], [0.6, 0.8], color='black', alpha=0.5)
plt.legend(['knn','lr','perfect'])
