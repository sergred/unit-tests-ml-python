# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
complete_data = pd.read_csv('../resources/data/adult/adult.csv')

# %% [markdown]
# ### Load dataset, resample to have balanced classes

# %%
rich = complete_data[complete_data['class'] == '>50K']
not_rich = complete_data[complete_data['class'] != '>50K'].sample(len(rich))

data = pd.concat([rich, not_rich])

# %%
data
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 14      40           Private  121772     Assoc-voc             11
# 19      43  Self-emp-not-inc  292175       Masters             14
# 20      40           Private  193524     Doctorate             16
# 25      56         Local-gov  216851     Bachelors             13
# 27      54                 ?  180211  Some-college             10
# 38      31           Private   84154  Some-college             10
# 45      57       Federal-gov  337895     Bachelors             13
# 52      47           Private   51835   Prof-school             15
# 53      50       Federal-gov  251585     Bachelors             13
# 55      43           Private  237993  Some-college             10
# 63      42           Private  116632     Doctorate             16
# 67      53           Private  169846       HS-grad              9
# 68      49      Self-emp-inc  191681  Some-college             10
# 72      29  Self-emp-not-inc  162298     Bachelors             13
# 84      44           Private  343591       HS-grad              9
# 86      49         Local-gov  268234       HS-grad              9
# 89      43       Federal-gov  410867     Doctorate             16
# 94      34         Local-gov  226296     Bachelors             13
# 96      48  Self-emp-not-inc  191277     Doctorate             16
# 97      37           Private  202683  Some-college             10
# 100     76           Private  124191       Masters             14
# 101     44           Private  198282     Bachelors             13
# 105     32      Self-emp-inc  317660       HS-grad              9
# 111     38           Private   65324   Prof-school             15
# 112     56  Self-emp-not-inc  335605       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 27909   27           Private  219863       HS-grad              9
# 1045    28           Private  187160   Prof-school             15
# 7883    47  Self-emp-not-inc  174533  Some-college             10
# 23923   29         State-gov  245310  Some-college             10
# 7855    53         State-gov  153486  Some-college             10
# 18557   68  Self-emp-not-inc   89011     Doctorate             16
# 20709   24         State-gov  147719       Masters             14
# 13818   52           Private   99602       HS-grad              9
# 19076   62         State-gov   39630     Bachelors             13
# 24204   39           Private  325374  Some-college             10
# 25696   31           Private  377374  Some-college             10
# 28456   32  Self-emp-not-inc  210926          11th              7
# 31854   31           Private  191276     Assoc-voc             11
# 19641   25           Private  206600          10th              6
# 21797   44  Self-emp-not-inc   71269     Bachelors             13
# 18267   35           Private  143152  Some-college             10
# 20109   44           Private   67065     Assoc-voc             11
# 22121   54  Self-emp-not-inc   91506  Some-college             10
# 11297   52           Private  241444       1st-4th              2
# 10549   35           Private  335777  Some-college             10
# 23492   37           Private   61778     Bachelors             13
# 12399   35           Private  197365       HS-grad              9
# 27384   32           Private  204792          11th              7
# 32143   33           Private  249716       HS-grad              9
# 2057    34           Private  126838       HS-grad              9
# 20246   55  Self-emp-not-inc  147098           9th              5
# 16871   35           Private  187693       HS-grad              9
# 2875    29           Private  227890       HS-grad              9
# 30494   27           Private  150296       HS-grad              9
# 31002   19           Private  301911  Some-college             10
#
#            marital_status         occupation    relationship  \
# 7      Married-civ-spouse    Exec-managerial         Husband
# 8           Never-married     Prof-specialty   Not-in-family
# 9      Married-civ-spouse    Exec-managerial         Husband
# 10     Married-civ-spouse    Exec-managerial         Husband
# 11     Married-civ-spouse     Prof-specialty         Husband
# 14     Married-civ-spouse       Craft-repair         Husband
# 19               Divorced    Exec-managerial       Unmarried
# 20     Married-civ-spouse     Prof-specialty         Husband
# 25     Married-civ-spouse       Tech-support         Husband
# 27     Married-civ-spouse                  ?         Husband
# 38     Married-civ-spouse              Sales         Husband
# 45     Married-civ-spouse     Prof-specialty         Husband
# 52     Married-civ-spouse     Prof-specialty            Wife
# 53               Divorced    Exec-managerial   Not-in-family
# 55     Married-civ-spouse       Tech-support         Husband
# 63     Married-civ-spouse     Prof-specialty         Husband
# 67     Married-civ-spouse       Adm-clerical            Wife
# 68     Married-civ-spouse    Exec-managerial         Husband
# 72     Married-civ-spouse              Sales         Husband
# 84               Divorced       Craft-repair   Not-in-family
# 86     Married-civ-spouse    Protective-serv         Husband
# 89          Never-married     Prof-specialty   Not-in-family
# 94     Married-civ-spouse    Protective-serv         Husband
# 96     Married-civ-spouse     Prof-specialty         Husband
# 97     Married-civ-spouse              Sales         Husband
# 100    Married-civ-spouse    Exec-managerial         Husband
# 101    Married-civ-spouse    Exec-managerial         Husband
# 105    Married-civ-spouse       Craft-repair         Husband
# 111    Married-civ-spouse     Prof-specialty         Husband
# 112    Married-civ-spouse      Other-service         Husband
# ...                   ...                ...             ...
# 27909  Married-civ-spouse   Transport-moving         Husband
# 1045             Divorced     Prof-specialty       Unmarried
# 7883   Married-civ-spouse       Craft-repair         Husband
# 23923       Never-married     Prof-specialty   Not-in-family
# 7855   Married-civ-spouse    Farming-fishing         Husband
# 18557  Married-civ-spouse     Prof-specialty         Husband
# 20709       Never-married     Prof-specialty   Not-in-family
# 13818           Separated       Craft-repair       Own-child
# 19076  Married-civ-spouse     Prof-specialty         Husband
# 24204       Never-married       Adm-clerical   Not-in-family
# 25696            Divorced       Adm-clerical       Unmarried
# 28456           Separated  Handlers-cleaners       Unmarried
# 31854            Divorced  Handlers-cleaners       Unmarried
# 19641       Never-married      Other-service   Not-in-family
# 21797            Divorced    Exec-managerial   Not-in-family
# 18267  Married-civ-spouse       Adm-clerical            Wife
# 20109       Never-married    Priv-house-serv   Not-in-family
# 22121  Married-civ-spouse              Sales         Husband
# 11297  Married-civ-spouse       Craft-repair         Husband
# 10549            Divorced    Exec-managerial   Not-in-family
# 23492       Never-married    Farming-fishing   Not-in-family
# 12399  Married-civ-spouse    Farming-fishing         Husband
# 27384  Married-civ-spouse    Farming-fishing         Husband
# 32143       Never-married       Tech-support   Not-in-family
# 2057   Married-civ-spouse   Transport-moving         Husband
# 20246  Married-civ-spouse       Craft-repair         Husband
# 16871       Never-married  Machine-op-inspct       Own-child
# 2875        Never-married    Protective-serv  Other-relative
# 30494       Never-married      Other-service       Own-child
# 31002       Never-married              Sales       Own-child
#
#                      race     sex  capital_gain  capital_loss  hours_per_week  \
# 7                   White    Male             0             0              45
# 8                   White  Female         14084             0              50
# 9                   White    Male          5178             0              40
# 10                  Black    Male             0             0              80
# 11     Asian-Pac-Islander    Male             0             0              40
# 14     Asian-Pac-Islander    Male             0             0              40
# 19                  White  Female             0             0              45
# 20                  White    Male             0             0              60
# 25                  White    Male             0             0              40
# 27     Asian-Pac-Islander    Male             0             0              60
# 38                  White    Male             0             0              38
# 45                  Black    Male             0             0              40
# 52                  White  Female             0          1902              60
# 53                  White    Male             0             0              55
# 55                  White    Male             0             0              40
# 63                  White    Male             0             0              45
# 67                  White  Female             0             0              40
# 68                  White    Male             0             0              50
# 72                  White    Male             0             0              70
# 84                  White  Female         14344             0              40
# 86                  White    Male             0             0              40
# 89                  White  Female             0             0              50
# 94                  White    Male             0             0              40
# 96                  White    Male             0          1902              60
# 97                  White    Male             0             0              48
# 100                 White    Male             0             0              40
# 101                 White    Male         15024             0              60
# 105                 White    Male          7688             0              40
# 111                 White    Male             0             0              40
# 112                 White    Male             0          1887              50
# ...                   ...     ...           ...           ...             ...
# 27909               White    Male             0             0              40
# 1045                White    Male             0             0              55
# 7883                White    Male             0             0              40
# 23923               White    Male             0             0              35
# 7855                White    Male             0             0              50
# 18557               White    Male             0             0              50
# 20709  Asian-Pac-Islander    Male             0             0              20
# 13818               Black  Female             0             0              40
# 19076               White    Male             0             0              40
# 24204               White    Male             0             0              40
# 25696               Black  Female             0             0              40
# 28456               White  Female             0             0              40
# 31854               White  Female             0             0              40
# 19641               White    Male             0             0              24
# 21797               White    Male             0             0              40
# 18267               White  Female          3908             0              27
# 20109               White    Male           594             0              25
# 22121               White    Male             0             0              65
# 11297               Other    Male             0             0              50
# 10549               White    Male             0             0              40
# 23492               White    Male             0             0              30
# 12399               White    Male             0             0              40
# 27384               White    Male             0             0              40
# 32143               White    Male             0             0              45
# 2057                White    Male             0             0              40
# 20246               White    Male             0             0              50
# 16871               White    Male             0             0              40
# 2875                Black    Male             0             0              40
# 30494               White  Female             0             0              32
# 31002  Asian-Pac-Islander    Male             0             0              35
#
#       native_country  class
# 7      United-States   >50K
# 8      United-States   >50K
# 9      United-States   >50K
# 10     United-States   >50K
# 11             India   >50K
# 14                 ?   >50K
# 19     United-States   >50K
# 20     United-States   >50K
# 25     United-States   >50K
# 27             South   >50K
# 38                 ?   >50K
# 45     United-States   >50K
# 52          Honduras   >50K
# 53     United-States   >50K
# 55     United-States   >50K
# 63     United-States   >50K
# 67     United-States   >50K
# 68     United-States   >50K
# 72     United-States   >50K
# 84     United-States   >50K
# 86     United-States   >50K
# 89     United-States   >50K
# 94     United-States   >50K
# 96     United-States   >50K
# 97     United-States   >50K
# 100    United-States   >50K
# 101    United-States   >50K
# 105    United-States   >50K
# 111    United-States   >50K
# 112           Canada   >50K
# ...              ...    ...
# 27909  United-States  <=50K
# 1045   United-States  <=50K
# 7883   United-States  <=50K
# 23923  United-States  <=50K
# 7855   United-States  <=50K
# 18557         Canada  <=50K
# 20709          India  <=50K
# 13818  United-States  <=50K
# 19076  United-States  <=50K
# 24204  United-States  <=50K
# 25696          Japan  <=50K
# 28456      Nicaragua  <=50K
# 31854  United-States  <=50K
# 19641      Nicaragua  <=50K
# 21797  United-States  <=50K
# 18267  United-States  <=50K
# 20109  United-States  <=50K
# 22121  United-States  <=50K
# 11297    Puerto-Rico  <=50K
# 10549         Mexico  <=50K
# 23492  United-States  <=50K
# 12399  United-States  <=50K
# 27384  United-States  <=50K
# 32143  United-States  <=50K
# 2057   United-States  <=50K
# 20246  United-States  <=50K
# 16871  United-States  <=50K
# 2875   United-States  <=50K
# 30494  United-States  <=50K
# 31002           Laos  <=50K
#
# [15682 rows x 15 columns]

# %% [markdown]
# ### Train a feed forward network

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

import tensorflow as tf
from tensorflow import keras

import warnings
warnings.filterwarnings('ignore')

def labels_from(df):
    return np.array(df['class'] == '>50K')

train_data, heldout_data = train_test_split(data, test_size=0.2)
test_data, target_data = train_test_split(heldout_data, test_size=0.5)

y_train = labels_from(train_data)
y_test = labels_from(test_data)
y_target = labels_from(target_data)

categorical_columns = ['workclass', 'occupation', 'marital_status', 'education']

numeric_columns = ['hours_per_week', 'age']

feature_transformation = ColumnTransformer(transformers=[
    ('categorical_features', OneHotEncoder(handle_unknown='ignore'), categorical_columns),
    ('scaled_numeric', StandardScaler(), numeric_columns)
])

nn = keras.Sequential([
    keras.layers.Dense(4, activation=tf.nn.relu),
    keras.layers.Dense(2, activation=tf.nn.softmax)
])

nn.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

featurizer = feature_transformation.fit(train_data)

nn.fit(featurizer.transform(train_data).todense(), y_train, epochs=100)
# Out:
# Epoch 1/100
# 12545/12545 [==============================] - 0s 30us/step - loss: 0.5860 - acc: 0.6990
# Epoch 2/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4494 - acc: 0.7904
# Epoch 3/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4276 - acc: 0.8001
# Epoch 4/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4213 - acc: 0.8029
# Epoch 5/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4180 - acc: 0.8059
# Epoch 6/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4161 - acc: 0.8061
# Epoch 7/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4145 - acc: 0.8081
# Epoch 8/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4134 - acc: 0.8093
# Epoch 9/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4128 - acc: 0.8088
# Epoch 10/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4120 - acc: 0.8104
# Epoch 11/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4115 - acc: 0.8104
# Epoch 12/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4108 - acc: 0.8093
# Epoch 13/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4101 - acc: 0.8121
# Epoch 14/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4097 - acc: 0.8109
# Epoch 15/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4091 - acc: 0.8112
# Epoch 16/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4084 - acc: 0.8105
# Epoch 17/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4081 - acc: 0.8096
# Epoch 18/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4076 - acc: 0.8107
# Epoch 19/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4073 - acc: 0.8119
# Epoch 20/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4069 - acc: 0.8108
# Epoch 21/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4067 - acc: 0.8107
# Epoch 22/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4062 - acc: 0.8109
# Epoch 23/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4062 - acc: 0.8111
# Epoch 24/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4060 - acc: 0.8113
# Epoch 25/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4056 - acc: 0.8112
# Epoch 26/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4055 - acc: 0.8116
# Epoch 27/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4055 - acc: 0.8124
# Epoch 28/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4053 - acc: 0.8116
# Epoch 29/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4050 - acc: 0.8115
# Epoch 30/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4052 - acc: 0.8124
# Epoch 31/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4049 - acc: 0.8121
# Epoch 32/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4049 - acc: 0.8130
# Epoch 33/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4047 - acc: 0.8120
# Epoch 34/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4048 - acc: 0.8131
# Epoch 35/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4045 - acc: 0.8108
# Epoch 36/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4045 - acc: 0.8128
# Epoch 37/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4042 - acc: 0.8124
# Epoch 38/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4043 - acc: 0.8110
# Epoch 39/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4040 - acc: 0.8105
# Epoch 40/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4041 - acc: 0.8129
# Epoch 41/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4040 - acc: 0.8117
# Epoch 42/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4042 - acc: 0.8115
# Epoch 43/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4041 - acc: 0.8127
# Epoch 44/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4039 - acc: 0.8117
# Epoch 45/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4040 - acc: 0.8114
# Epoch 46/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4037 - acc: 0.8120
# Epoch 47/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4038 - acc: 0.8118
# Epoch 48/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4037 - acc: 0.8121
# Epoch 49/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4035 - acc: 0.8126
# Epoch 50/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4038 - acc: 0.8135
# Epoch 51/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4036 - acc: 0.8124
# Epoch 52/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4036 - acc: 0.8128
# Epoch 53/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4037 - acc: 0.8124
# Epoch 54/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4033 - acc: 0.8128
# Epoch 55/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4034 - acc: 0.8119
# Epoch 56/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4033 - acc: 0.8128
# Epoch 57/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4034 - acc: 0.8133
# Epoch 58/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4034 - acc: 0.8131
# Epoch 59/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4038 - acc: 0.8125
# Epoch 60/100
# 12545/12545 [==============================] - 0s 21us/step - loss: 0.4030 - acc: 0.8136
# Epoch 61/100
# 12545/12545 [==============================] - 0s 21us/step - loss: 0.4031 - acc: 0.8123
# Epoch 62/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4033 - acc: 0.8136
# Epoch 63/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4032 - acc: 0.8128
# Epoch 64/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4032 - acc: 0.8122
# Epoch 65/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4033 - acc: 0.8118
# Epoch 66/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4030 - acc: 0.8132
# Epoch 67/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4031 - acc: 0.8124
# Epoch 68/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4031 - acc: 0.8132
# Epoch 69/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4029 - acc: 0.8120
# Epoch 70/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4031 - acc: 0.8132
# Epoch 71/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4034 - acc: 0.8132
# Epoch 72/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4030 - acc: 0.8132
# Epoch 73/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4031 - acc: 0.8143
# Epoch 74/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4033 - acc: 0.8135
# Epoch 75/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4029 - acc: 0.8126
# Epoch 76/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4029 - acc: 0.8120
# Epoch 77/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4031 - acc: 0.8122
# Epoch 78/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4029 - acc: 0.8132
# Epoch 79/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4029 - acc: 0.8116
# Epoch 80/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4027 - acc: 0.8128
# Epoch 81/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4030 - acc: 0.8124
# Epoch 82/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4029 - acc: 0.8119
# Epoch 83/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4029 - acc: 0.8128
# Epoch 84/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4030 - acc: 0.8108
# Epoch 85/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4030 - acc: 0.8120
# Epoch 86/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4031 - acc: 0.8124
# Epoch 87/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4027 - acc: 0.8114
# Epoch 88/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4026 - acc: 0.8123
# Epoch 89/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4032 - acc: 0.8123
# Epoch 90/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4029 - acc: 0.8140
# Epoch 91/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4028 - acc: 0.8123
# Epoch 92/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4026 - acc: 0.8131
# Epoch 93/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4028 - acc: 0.8125
# Epoch 94/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4029 - acc: 0.8127
# Epoch 95/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4027 - acc: 0.8120
# Epoch 96/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4027 - acc: 0.8132
# Epoch 97/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4028 - acc: 0.8124
# Epoch 98/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4031 - acc: 0.8139
# Epoch 99/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4027 - acc: 0.8133
# Epoch 100/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4026 - acc: 0.8114

# %%
class ModelWithFeaturization:

    def __init__(self, nn, featurizer):
        self.nn = nn
        self.featurizer = featurizer
        
    def predict(self, df):
        return [np.argmax(p) for p in self.nn.predict(self.featurizer.transform(df).todense())]
    
    def predict_proba(self, df):
        return self.nn.predict(self.featurizer.transform(df).todense())
    
model = ModelWithFeaturization(nn, featurizer)

# %%
score_on_train_data = accuracy_score(y_train, model.predict(train_data))
score_on_noncorrupted_test_data = accuracy_score(y_test, model.predict(test_data))
score_on_noncorrupted_target_data = accuracy_score(y_target, model.predict(target_data))

print("score on train data: ", score_on_train_data)
print("score on test data: ", score_on_noncorrupted_test_data)
print("score on target data: ", score_on_noncorrupted_target_data)
# Out:
# score on train data:  0.8150657632522917
# score on test data:  0.7991071428571429
# score on target data:  0.7973231357552581

# %% [markdown]
# ### Introduce errors (missing values) into unseen test data, record resulting class probability entropies and accuracy score as inputs for the meta regressor

# %%
import random
from scipy.stats import entropy
from tqdm import tqdm

def delete_cells(df, fraction, columns):
    # we operate on a copy of the data
    corrupted_df = df.copy(deep=True)
    
    row_indexes = [row for row in range(corrupted_df.shape[0])]
    # pick random examples
    num_rows_to_pick = int(round(fraction * len(row_indexes)))
    for random_row_index in random.sample(row_indexes, num_rows_to_pick):           
        # delete all specified values in the target columns
        for column in columns:
            column_index = df.columns.get_loc(column)
            corrupted_df.iat[random_row_index, column_index] = 'n/a'
    
    return corrupted_df

generated_training_data = []

for num_columns_affected in tqdm(range(1, 5)):
    for fraction_of_values_to_delete in [0.0, 0.05, 0.25, 0.5, 0.75, 0.99]:    
        for _ in range(0, 100):        
            columns_affected = np.random.choice(categorical_columns, num_columns_affected)        

            corrupted_test_data = delete_cells(test_data, fraction_of_values_to_delete, columns_affected)

            predictions = model.predict_proba(corrupted_test_data)
                        
            entropy_good = entropy(np.transpose(predictions)[0])
            entropy_bad = entropy(np.transpose(predictions)[1])           

            score_on_corrupted_test_data = accuracy_score(y_test, model.predict(corrupted_test_data))

            generated_training_data.append([entropy_good, entropy_bad, score_on_corrupted_test_data])
# Out:
# 100%|██████████| 4/4 [01:31<00:00, 22.80s/it]

# %% [markdown]
# ### Plot relation between entropy of predicted class probabilities and accuracy

# %%
entropies_good = np.transpose(generated_training_data)[0]
entropies_bad = np.transpose(generated_training_data)[1]
accuracies = np.transpose(generated_training_data)[2]

plt.scatter(entropies_good, accuracies)
plt.scatter(entropies_bad, accuracies)
plt.xlabel("entropy of class probabilities")
plt.ylabel("accuracy")
plt.show()

# %% [markdown]
# ### Fit a simple regression model to the generated training data

# %%
from sklearn.linear_model import LinearRegression

X = np.array(generated_training_data)[:,:2]
y = np.array(generated_training_data)[:,2]

meta_regressor_pipeline = Pipeline([
    ('scaling', StandardScaler()), 
    ('learner', LinearRegression())
])

meta_regressor = meta_regressor_pipeline.fit(X, y)

# %% [markdown]
# ### Evaluate regression model in predicting effects of errors in the unseen target data

# %%
predicted_scores = []
true_scores = []

for num_columns_affected in tqdm(range(1, 5)):
    for fraction_of_values_to_delete in [0.05, 0.25, 0.5, 0.75, 0.99]:    
        for _ in range(0, 100):        
            columns_affected = np.random.choice(categorical_columns, num_columns_affected)        

            corrupted_target_data = delete_cells(target_data, fraction_of_values_to_delete, columns_affected)

            predictions = model.predict_proba(corrupted_target_data)
            
            entropy_good = entropy(np.transpose(predictions)[0])
            entropy_bad = entropy(np.transpose(predictions)[1])           

            score_on_corrupted_target_data = accuracy_score(y_target, model.predict(corrupted_target_data))
            predicted_score_on_corrupted_target_data = meta_regressor.predict([[entropy_good, entropy_bad]])
            
            predicted_scores.append(predicted_score_on_corrupted_target_data)
            true_scores.append(score_on_corrupted_target_data)
# Out:
# 100%|██████████| 4/4 [01:23<00:00, 20.85s/it]

# %%
from scipy import stats

gradient, intercept, _, _, _ = stats.linregress(np.array(true_scores).flatten(), np.array(predicted_scores).flatten())

plt.scatter(true_scores, predicted_scores, alpha=0.05)

x1 = np.linspace(0.6, 0.8, 100)
plt.plot(x1, gradient * x1 + intercept, '-')

plt.xlabel("true accuracy on corrupted target data")
plt.ylabel("predicted accuracy on corrupted target data")
plt.plot([0.6, 0.8], [0.6, 0.8], color='black', alpha=0.5)
plt.show()
