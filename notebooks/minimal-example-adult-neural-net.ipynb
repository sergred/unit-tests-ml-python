# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
complete_data = pd.read_csv('../resources/data/adult/adult.csv')

# %% [markdown]
# ### Load dataset, resample to have balanced classes

# %%
rich = complete_data[complete_data['class'] == '>50K']
not_rich = complete_data[complete_data['class'] != '>50K'].sample(len(rich))

data = pd.concat([rich, not_rich])

# %%
data
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 14      40           Private  121772     Assoc-voc             11
# 19      43  Self-emp-not-inc  292175       Masters             14
# 20      40           Private  193524     Doctorate             16
# 25      56         Local-gov  216851     Bachelors             13
# 27      54                 ?  180211  Some-college             10
# 38      31           Private   84154  Some-college             10
# 45      57       Federal-gov  337895     Bachelors             13
# 52      47           Private   51835   Prof-school             15
# 53      50       Federal-gov  251585     Bachelors             13
# 55      43           Private  237993  Some-college             10
# 63      42           Private  116632     Doctorate             16
# 67      53           Private  169846       HS-grad              9
# 68      49      Self-emp-inc  191681  Some-college             10
# 72      29  Self-emp-not-inc  162298     Bachelors             13
# 84      44           Private  343591       HS-grad              9
# 86      49         Local-gov  268234       HS-grad              9
# 89      43       Federal-gov  410867     Doctorate             16
# 94      34         Local-gov  226296     Bachelors             13
# 96      48  Self-emp-not-inc  191277     Doctorate             16
# 97      37           Private  202683  Some-college             10
# 100     76           Private  124191       Masters             14
# 101     44           Private  198282     Bachelors             13
# 105     32      Self-emp-inc  317660       HS-grad              9
# 111     38           Private   65324   Prof-school             15
# 112     56  Self-emp-not-inc  335605       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 12868   46       Federal-gov   55237  Some-college             10
# 3123    42           Private   54102     Assoc-voc             11
# 13007   19           Private   28145       HS-grad              9
# 1529    37           Private   26898       HS-grad              9
# 680     29         Local-gov   92262       HS-grad              9
# 29366   22           Private  336215    Assoc-acdm             12
# 8900    24           Private  172612       HS-grad              9
# 2126    20                 ?   81853  Some-college             10
# 26228   21           Private  118401  Some-college             10
# 18694   19           Private  144911  Some-college             10
# 1308    43           Private   85995       HS-grad              9
# 23001   29           Private  337693       5th-6th              3
# 10563   23         State-gov  103588  Some-college             10
# 1155    34           Private  117529  Some-college             10
# 15788   67           Private  101132       7th-8th              4
# 5093    34           Private  178615       HS-grad              9
# 19681   31           Private   94235     Bachelors             13
# 12498   28  Self-emp-not-inc   96219     Bachelors             13
# 30287   58           Private  357788       HS-grad              9
# 7041    35           Private  141896          12th              8
# 24781   20                 ?  189740  Some-college             10
# 10473   31           Private  356882       HS-grad              9
# 22490   23           Private  183789       HS-grad              9
# 12798   46         Local-gov  199281     Bachelors             13
# 19594   44  Self-emp-not-inc  218653     Bachelors             13
# 22744   44  Self-emp-not-inc  194636       HS-grad              9
# 32065   45           Private   30289          12th              8
# 9272    29           Private  147340  Some-college             10
# 6285    19                 ?  169324  Some-college             10
# 902     22           Private   99697       HS-grad              9
#
#            marital_status         occupation   relationship  \
# 7      Married-civ-spouse    Exec-managerial        Husband
# 8           Never-married     Prof-specialty  Not-in-family
# 9      Married-civ-spouse    Exec-managerial        Husband
# 10     Married-civ-spouse    Exec-managerial        Husband
# 11     Married-civ-spouse     Prof-specialty        Husband
# 14     Married-civ-spouse       Craft-repair        Husband
# 19               Divorced    Exec-managerial      Unmarried
# 20     Married-civ-spouse     Prof-specialty        Husband
# 25     Married-civ-spouse       Tech-support        Husband
# 27     Married-civ-spouse                  ?        Husband
# 38     Married-civ-spouse              Sales        Husband
# 45     Married-civ-spouse     Prof-specialty        Husband
# 52     Married-civ-spouse     Prof-specialty           Wife
# 53               Divorced    Exec-managerial  Not-in-family
# 55     Married-civ-spouse       Tech-support        Husband
# 63     Married-civ-spouse     Prof-specialty        Husband
# 67     Married-civ-spouse       Adm-clerical           Wife
# 68     Married-civ-spouse    Exec-managerial        Husband
# 72     Married-civ-spouse              Sales        Husband
# 84               Divorced       Craft-repair  Not-in-family
# 86     Married-civ-spouse    Protective-serv        Husband
# 89          Never-married     Prof-specialty  Not-in-family
# 94     Married-civ-spouse    Protective-serv        Husband
# 96     Married-civ-spouse     Prof-specialty        Husband
# 97     Married-civ-spouse              Sales        Husband
# 100    Married-civ-spouse    Exec-managerial        Husband
# 101    Married-civ-spouse    Exec-managerial        Husband
# 105    Married-civ-spouse       Craft-repair        Husband
# 111    Married-civ-spouse     Prof-specialty        Husband
# 112    Married-civ-spouse      Other-service        Husband
# ...                   ...                ...            ...
# 12868            Divorced  Machine-op-inspct      Unmarried
# 3123             Divorced       Adm-clerical      Unmarried
# 13007       Never-married      Other-service      Own-child
# 1529             Divorced    Exec-managerial      Unmarried
# 680         Never-married    Protective-serv      Own-child
# 29366       Never-married       Adm-clerical  Not-in-family
# 8900   Married-civ-spouse       Craft-repair        Husband
# 2126        Never-married                  ?      Own-child
# 26228       Never-married      Other-service  Not-in-family
# 18694       Never-married      Other-service      Own-child
# 1308   Married-civ-spouse              Sales        Husband
# 23001       Never-married      Other-service      Own-child
# 10563       Never-married       Adm-clerical      Own-child
# 1155   Married-civ-spouse    Farming-fishing        Husband
# 15788  Married-civ-spouse       Craft-repair        Husband
# 5093   Married-civ-spouse  Machine-op-inspct        Husband
# 19681  Married-civ-spouse       Craft-repair        Husband
# 12498  Married-civ-spouse              Sales           Wife
# 30287  Married-civ-spouse       Craft-repair        Husband
# 7041   Married-civ-spouse       Craft-repair        Husband
# 24781       Never-married                  ?      Own-child
# 10473  Married-civ-spouse  Machine-op-inspct        Husband
# 22490       Never-married              Sales      Own-child
# 12798           Separated     Prof-specialty      Unmarried
# 19594            Divorced       Craft-repair      Own-child
# 22744  Married-civ-spouse       Craft-repair        Husband
# 32065  Married-civ-spouse       Craft-repair        Husband
# 9272        Never-married              Sales      Own-child
# 6285        Never-married                  ?      Own-child
# 902         Never-married  Handlers-cleaners      Own-child
#
#                      race     sex  capital_gain  capital_loss  hours_per_week  \
# 7                   White    Male             0             0              45
# 8                   White  Female         14084             0              50
# 9                   White    Male          5178             0              40
# 10                  Black    Male             0             0              80
# 11     Asian-Pac-Islander    Male             0             0              40
# 14     Asian-Pac-Islander    Male             0             0              40
# 19                  White  Female             0             0              45
# 20                  White    Male             0             0              60
# 25                  White    Male             0             0              40
# 27     Asian-Pac-Islander    Male             0             0              60
# 38                  White    Male             0             0              38
# 45                  Black    Male             0             0              40
# 52                  White  Female             0          1902              60
# 53                  White    Male             0             0              55
# 55                  White    Male             0             0              40
# 63                  White    Male             0             0              45
# 67                  White  Female             0             0              40
# 68                  White    Male             0             0              50
# 72                  White    Male             0             0              70
# 84                  White  Female         14344             0              40
# 86                  White    Male             0             0              40
# 89                  White  Female             0             0              50
# 94                  White    Male             0             0              40
# 96                  White    Male             0          1902              60
# 97                  White    Male             0             0              48
# 100                 White    Male             0             0              40
# 101                 White    Male         15024             0              60
# 105                 White    Male          7688             0              40
# 111                 White    Male             0             0              40
# 112                 White    Male             0          1887              50
# ...                   ...     ...           ...           ...             ...
# 12868               White    Male             0             0              40
# 3123                White  Female             0             0              40
# 13007               White  Female             0             0              52
# 1529                White  Female             0             0              12
# 680                 White    Male             0             0              48
# 29366               White  Female             0             0              25
# 8900                White    Male             0             0              40
# 2126   Asian-Pac-Islander  Female             0             0              15
# 26228               White  Female             0             0              30
# 18694               White    Male             0             0              20
# 1308                White    Male             0             0              45
# 23001               White  Female             0             0              40
# 10563               White    Male             0             0              25
# 1155                White    Male             0             0              54
# 15788               White    Male          1797             0              40
# 5093                White    Male             0             0              40
# 19681               White    Male             0             0              46
# 12498               White  Female             0             0               5
# 30287               Black    Male             0             0              40
# 7041                White    Male             0             0              40
# 24781               White  Female             0             0              32
# 10473               White    Male          5013             0              40
# 22490               White    Male             0             0              40
# 12798               White    Male             0             0              40
# 19594               White    Male             0             0              40
# 22744               White    Male          3137             0              50
# 32065               White    Male             0             0              40
# 9272                White  Female             0             0              40
# 6285                White    Male             0             0              10
# 902                 White  Female             0             0              40
#
#       native_country  class
# 7      United-States   >50K
# 8      United-States   >50K
# 9      United-States   >50K
# 10     United-States   >50K
# 11             India   >50K
# 14                 ?   >50K
# 19     United-States   >50K
# 20     United-States   >50K
# 25     United-States   >50K
# 27             South   >50K
# 38                 ?   >50K
# 45     United-States   >50K
# 52          Honduras   >50K
# 53     United-States   >50K
# 55     United-States   >50K
# 63     United-States   >50K
# 67     United-States   >50K
# 68     United-States   >50K
# 72     United-States   >50K
# 84     United-States   >50K
# 86     United-States   >50K
# 89     United-States   >50K
# 94     United-States   >50K
# 96     United-States   >50K
# 97     United-States   >50K
# 100    United-States   >50K
# 101    United-States   >50K
# 105    United-States   >50K
# 111    United-States   >50K
# 112           Canada   >50K
# ...              ...    ...
# 12868  United-States  <=50K
# 3123   United-States  <=50K
# 13007  United-States  <=50K
# 1529   United-States  <=50K
# 680    United-States  <=50K
# 29366  United-States  <=50K
# 8900   United-States  <=50K
# 2126   United-States  <=50K
# 26228  United-States  <=50K
# 18694  United-States  <=50K
# 1308   United-States  <=50K
# 23001    El-Salvador  <=50K
# 10563  United-States  <=50K
# 1155          Mexico  <=50K
# 15788  United-States  <=50K
# 5093   United-States  <=50K
# 19681  United-States  <=50K
# 12498  United-States  <=50K
# 30287  United-States  <=50K
# 7041   United-States  <=50K
# 24781  United-States  <=50K
# 10473  United-States  <=50K
# 22490  United-States  <=50K
# 12798  United-States  <=50K
# 19594  United-States  <=50K
# 22744  United-States  <=50K
# 32065  United-States  <=50K
# 9272   United-States  <=50K
# 6285   United-States  <=50K
# 902    United-States  <=50K
#
# [15682 rows x 15 columns]

# %% [markdown]
# ### Train a feed forward network

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

import tensorflow as tf
from tensorflow import keras

import warnings
warnings.filterwarnings('ignore')

def labels_from(df):
    return np.array(df['class'] == '>50K')

train_data, heldout_data = train_test_split(data, test_size=0.2)
test_data, target_data = train_test_split(heldout_data, test_size=0.5)

y_train = labels_from(train_data)
y_test = labels_from(test_data)
y_target = labels_from(target_data)

categorical_columns = ['workclass', 'occupation', 'marital_status', 'education']

numeric_columns = ['hours_per_week', 'age']

feature_transformation = ColumnTransformer(transformers=[
    ('categorical_features', OneHotEncoder(handle_unknown='ignore'), categorical_columns),
    ('scaled_numeric', StandardScaler(), numeric_columns)
])

nn = keras.Sequential([
    keras.layers.Dense(4, activation=tf.nn.relu),
    keras.layers.Dense(2, activation=tf.nn.softmax)
])

nn.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

featurizer = feature_transformation.fit(train_data)

nn.fit(featurizer.transform(train_data).todense(), y_train, epochs=100)
# Out:
# Epoch 1/100
# 12545/12545 [==============================] - 0s 36us/step - loss: 0.5144 - acc: 0.7482
# Epoch 2/100
# 12545/12545 [==============================] - 0s 32us/step - loss: 0.4426 - acc: 0.7886
# Epoch 3/100
# 12545/12545 [==============================] - 0s 28us/step - loss: 0.4310 - acc: 0.7987
# Epoch 4/100
# 12545/12545 [==============================] - 0s 26us/step - loss: 0.4272 - acc: 0.7997
# Epoch 5/100
# 12545/12545 [==============================] - 0s 29us/step - loss: 0.4252 - acc: 0.8019
# Epoch 6/100
# 12545/12545 [==============================] - 0s 35us/step - loss: 0.4243 - acc: 0.8029
# Epoch 7/100
# 12545/12545 [==============================] - 0s 35us/step - loss: 0.4234 - acc: 0.8026
# Epoch 8/100
# 12545/12545 [==============================] - 0s 34us/step - loss: 0.4224 - acc: 0.8032
# Epoch 9/100
# 12545/12545 [==============================] - 0s 32us/step - loss: 0.4214 - acc: 0.8045
# Epoch 10/100
# 12545/12545 [==============================] - 0s 35us/step - loss: 0.4204 - acc: 0.8035
# Epoch 11/100
# 12545/12545 [==============================] - 0s 29us/step - loss: 0.4196 - acc: 0.8041
# Epoch 12/100
# 12545/12545 [==============================] - 0s 28us/step - loss: 0.4189 - acc: 0.8043
# Epoch 13/100
# 12545/12545 [==============================] - 0s 26us/step - loss: 0.4182 - acc: 0.8054
# Epoch 14/100
# 12545/12545 [==============================] - 0s 23us/step - loss: 0.4177 - acc: 0.8050
# Epoch 15/100
# 12545/12545 [==============================] - 0s 25us/step - loss: 0.4172 - acc: 0.8062
# Epoch 16/100
# 12545/12545 [==============================] - 0s 29us/step - loss: 0.4165 - acc: 0.8061
# Epoch 17/100
# 12545/12545 [==============================] - 0s 25us/step - loss: 0.4161 - acc: 0.8059
# Epoch 18/100
# 12545/12545 [==============================] - 1s 59us/step - loss: 0.4156 - acc: 0.8041
# Epoch 19/100
# 12545/12545 [==============================] - 1s 81us/step - loss: 0.4152 - acc: 0.8055
# Epoch 20/100
# 12545/12545 [==============================] - 1s 47us/step - loss: 0.4150 - acc: 0.8053
# Epoch 21/100
# 12545/12545 [==============================] - 0s 30us/step - loss: 0.4145 - acc: 0.8065
# Epoch 22/100
# 12545/12545 [==============================] - 1s 62us/step - loss: 0.4144 - acc: 0.8074
# Epoch 23/100
# 12545/12545 [==============================] - 0s 33us/step - loss: 0.4140 - acc: 0.8063
# Epoch 24/100
# 12545/12545 [==============================] - 0s 31us/step - loss: 0.4138 - acc: 0.8072
# Epoch 25/100
# 12545/12545 [==============================] - 0s 31us/step - loss: 0.4136 - acc: 0.8074
# Epoch 26/100
# 12545/12545 [==============================] - 0s 26us/step - loss: 0.4132 - acc: 0.8073
# Epoch 27/100
# 12545/12545 [==============================] - 0s 28us/step - loss: 0.4127 - acc: 0.8065
# Epoch 28/100
# 12545/12545 [==============================] - 0s 30us/step - loss: 0.4126 - acc: 0.8070
# Epoch 29/100
# 12545/12545 [==============================] - 0s 28us/step - loss: 0.4125 - acc: 0.8073
# Epoch 30/100
# 12545/12545 [==============================] - 0s 30us/step - loss: 0.4123 - acc: 0.8069
# Epoch 31/100
# 12545/12545 [==============================] - 0s 28us/step - loss: 0.4118 - acc: 0.8096
# Epoch 32/100
# 12545/12545 [==============================] - 0s 27us/step - loss: 0.4118 - acc: 0.8082
# Epoch 33/100
# 12545/12545 [==============================] - 0s 28us/step - loss: 0.4115 - acc: 0.8081
# Epoch 34/100
# 12545/12545 [==============================] - 0s 31us/step - loss: 0.4113 - acc: 0.8084
# Epoch 35/100
# 12545/12545 [==============================] - 0s 28us/step - loss: 0.4112 - acc: 0.8090
# Epoch 36/100
# 12545/12545 [==============================] - 0s 30us/step - loss: 0.4111 - acc: 0.8084
# Epoch 37/100
# 12545/12545 [==============================] - 0s 30us/step - loss: 0.4109 - acc: 0.8091
# Epoch 38/100
# 12545/12545 [==============================] - 0s 30us/step - loss: 0.4108 - acc: 0.8096
# Epoch 39/100
# 12545/12545 [==============================] - 0s 30us/step - loss: 0.4107 - acc: 0.8088
# Epoch 40/100
# 12545/12545 [==============================] - 0s 30us/step - loss: 0.4106 - acc: 0.8092
# Epoch 41/100
# 12545/12545 [==============================] - 0s 28us/step - loss: 0.4105 - acc: 0.8095
# Epoch 42/100
# 12545/12545 [==============================] - 0s 25us/step - loss: 0.4102 - acc: 0.8078
# Epoch 43/100
# 12545/12545 [==============================] - 0s 30us/step - loss: 0.4103 - acc: 0.8092
# Epoch 44/100
# 12545/12545 [==============================] - 0s 29us/step - loss: 0.4102 - acc: 0.8095
# Epoch 45/100
# 12545/12545 [==============================] - 0s 28us/step - loss: 0.4102 - acc: 0.8098
# Epoch 46/100
# 12545/12545 [==============================] - 0s 27us/step - loss: 0.4102 - acc: 0.8091
# Epoch 47/100
# 12545/12545 [==============================] - 0s 27us/step - loss: 0.4097 - acc: 0.8087
# Epoch 48/100
# 12545/12545 [==============================] - 0s 26us/step - loss: 0.4096 - acc: 0.8100
# Epoch 49/100
# 12545/12545 [==============================] - 0s 25us/step - loss: 0.4091 - acc: 0.8101
# Epoch 50/100
# 12545/12545 [==============================] - 0s 28us/step - loss: 0.4093 - acc: 0.8104
# Epoch 51/100
# 12545/12545 [==============================] - 0s 30us/step - loss: 0.4091 - acc: 0.8088
# Epoch 52/100
# 12545/12545 [==============================] - 0s 28us/step - loss: 0.4091 - acc: 0.8113
# Epoch 53/100
# 12545/12545 [==============================] - 0s 30us/step - loss: 0.4088 - acc: 0.8087
# Epoch 54/100
# 12545/12545 [==============================] - 0s 29us/step - loss: 0.4091 - acc: 0.8112
# Epoch 55/100
# 12545/12545 [==============================] - 0s 28us/step - loss: 0.4088 - acc: 0.8089
# Epoch 56/100
# 12545/12545 [==============================] - 0s 29us/step - loss: 0.4087 - acc: 0.8095
# Epoch 57/100
# 12545/12545 [==============================] - 0s 28us/step - loss: 0.4088 - acc: 0.8101
# Epoch 58/100
# 12545/12545 [==============================] - 0s 33us/step - loss: 0.4083 - acc: 0.8087
# Epoch 59/100
# 12545/12545 [==============================] - 1s 49us/step - loss: 0.4088 - acc: 0.8082
# Epoch 60/100
# 12545/12545 [==============================] - 1s 53us/step - loss: 0.4083 - acc: 0.8104
# Epoch 61/100
# 12545/12545 [==============================] - 1s 60us/step - loss: 0.4083 - acc: 0.8100
# Epoch 62/100
# 12545/12545 [==============================] - 1s 53us/step - loss: 0.4084 - acc: 0.8106
# Epoch 63/100
# 12545/12545 [==============================] - 1s 68us/step - loss: 0.4083 - acc: 0.8108
# Epoch 64/100
# 12545/12545 [==============================] - 0s 34us/step - loss: 0.4084 - acc: 0.8098
# Epoch 65/100
# 12545/12545 [==============================] - 1s 44us/step - loss: 0.4080 - acc: 0.8104
# Epoch 66/100
# 12545/12545 [==============================] - 1s 41us/step - loss: 0.4080 - acc: 0.8110
# Epoch 67/100
# 12545/12545 [==============================] - 1s 42us/step - loss: 0.4080 - acc: 0.8099
# Epoch 68/100
# 12545/12545 [==============================] - 0s 38us/step - loss: 0.4081 - acc: 0.8099
# Epoch 69/100
# 12545/12545 [==============================] - 0s 33us/step - loss: 0.4081 - acc: 0.8094
# Epoch 70/100
# 12545/12545 [==============================] - 1s 54us/step - loss: 0.4080 - acc: 0.8104
# Epoch 71/100
# 12545/12545 [==============================] - 0s 28us/step - loss: 0.4077 - acc: 0.8101
# Epoch 72/100
# 12545/12545 [==============================] - 0s 27us/step - loss: 0.4080 - acc: 0.8090
# Epoch 73/100
# 12545/12545 [==============================] - 0s 22us/step - loss: 0.4077 - acc: 0.8102
# Epoch 74/100
# 12545/12545 [==============================] - 0s 22us/step - loss: 0.4077 - acc: 0.8092
# Epoch 75/100
# 12545/12545 [==============================] - 0s 16us/step - loss: 0.4078 - acc: 0.8101
# Epoch 76/100
# 12545/12545 [==============================] - 0s 15us/step - loss: 0.4076 - acc: 0.8095
# Epoch 77/100
# 12545/12545 [==============================] - 0s 15us/step - loss: 0.4077 - acc: 0.8101
# Epoch 78/100
# 12545/12545 [==============================] - 0s 15us/step - loss: 0.4076 - acc: 0.8097
# Epoch 79/100
# 12545/12545 [==============================] - 0s 21us/step - loss: 0.4074 - acc: 0.8098
# Epoch 80/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4075 - acc: 0.8104
# Epoch 81/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4074 - acc: 0.8107
# Epoch 82/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4075 - acc: 0.8110
# Epoch 83/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4075 - acc: 0.8105
# Epoch 84/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4076 - acc: 0.8107
# Epoch 85/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4075 - acc: 0.8081
# Epoch 86/100
# 12545/12545 [==============================] - 0s 17us/step - loss: 0.4078 - acc: 0.8105
# Epoch 87/100
# 12545/12545 [==============================] - 0s 17us/step - loss: 0.4073 - acc: 0.8103
# Epoch 88/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4072 - acc: 0.8107
# Epoch 89/100
# 12545/12545 [==============================] - 0s 15us/step - loss: 0.4071 - acc: 0.8112
# Epoch 90/100
# 12545/12545 [==============================] - 0s 14us/step - loss: 0.4070 - acc: 0.8104
# Epoch 91/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4072 - acc: 0.8116
# Epoch 92/100
# 12545/12545 [==============================] - 1s 74us/step - loss: 0.4074 - acc: 0.8092
# Epoch 93/100
# 12545/12545 [==============================] - 1s 66us/step - loss: 0.4072 - acc: 0.8112
# Epoch 94/100
# 12545/12545 [==============================] - 1s 52us/step - loss: 0.4073 - acc: 0.8101
# Epoch 95/100
# 12545/12545 [==============================] - 1s 42us/step - loss: 0.4072 - acc: 0.8096
# Epoch 96/100
# 12545/12545 [==============================] - 0s 28us/step - loss: 0.4069 - acc: 0.8097
# Epoch 97/100
# 12545/12545 [==============================] - 0s 28us/step - loss: 0.4074 - acc: 0.8103
# Epoch 98/100
# 12545/12545 [==============================] - 1s 52us/step - loss: 0.4068 - acc: 0.8089
# Epoch 99/100
# 12545/12545 [==============================] - 0s 28us/step - loss: 0.4070 - acc: 0.8107
# Epoch 100/100
# 12545/12545 [==============================] - 0s 34us/step - loss: 0.4070 - acc: 0.8100

# %%
class ModelWithFeaturization:

    def __init__(self, nn, featurizer):
        self.nn = nn
        self.featurizer = featurizer
        
    def predict(self, df):
        return [np.argmax(p) for p in self.nn.predict(self.featurizer.transform(df).todense())]
    
    def predict_proba(self, df):
        return self.nn.predict(self.featurizer.transform(df).todense())
    
model = ModelWithFeaturization(nn, featurizer)

# %%
score_on_train_data = accuracy_score(y_train, model.predict(train_data))
score_on_noncorrupted_test_data = accuracy_score(y_test, model.predict(test_data))
score_on_noncorrupted_target_data = accuracy_score(y_target, model.predict(target_data))

print("score on train data: ", score_on_train_data)
print("score on test data: ", score_on_noncorrupted_test_data)
print("score on target data: ", score_on_noncorrupted_target_data)
# Out:
# score on train data:  0.8112395376644082
# score on test data:  0.8016581632653061
# score on target data:  0.8138942001274697

# %% [markdown]
# ### Introduce errors (missing values) into unseen test data, record resulting class probability entropies and accuracy score as inputs for the meta regressor

# %%
import random
from scipy.stats import entropy
from tqdm import tqdm

def delete_cells(df, fraction, columns):
    # we operate on a copy of the data
    corrupted_df = df.copy(deep=True)
    
    row_indexes = [row for row in range(corrupted_df.shape[0])]
    # pick random examples
    num_rows_to_pick = int(round(fraction * len(row_indexes)))
    for random_row_index in random.sample(row_indexes, num_rows_to_pick):           
        # delete all specified values in the target columns
        for column in columns:
            column_index = df.columns.get_loc(column)
            corrupted_df.iat[random_row_index, column_index] = 'n/a'
    
    return corrupted_df

generated_training_data = []

for num_columns_affected in tqdm(range(1, 5)):
    for fraction_of_values_to_delete in [0.0, 0.05, 0.25, 0.5, 0.75, 0.99]:    
        for _ in range(0, 100):        
            columns_affected = np.random.choice(categorical_columns, num_columns_affected)        

            corrupted_test_data = delete_cells(test_data, fraction_of_values_to_delete, columns_affected)

            predictions = model.predict_proba(corrupted_test_data)
                        
            entropy_good = entropy(np.transpose(predictions)[0])
            entropy_bad = entropy(np.transpose(predictions)[1])           

            score_on_corrupted_test_data = accuracy_score(y_test, model.predict(corrupted_test_data))

            generated_training_data.append([entropy_good, entropy_bad, score_on_corrupted_test_data])
# Out:
# 100%|██████████| 4/4 [02:15<00:00, 34.85s/it]

# %% [markdown]
# ### Plot relation between entropy of predicted class probabilities and accuracy

# %%
entropies_good = np.transpose(generated_training_data)[0]
entropies_bad = np.transpose(generated_training_data)[1]
accuracies = np.transpose(generated_training_data)[2]

plt.scatter(entropies_good, accuracies)
plt.scatter(entropies_bad, accuracies)
plt.xlabel("entropy of class probabilities")
plt.ylabel("accuracy")
plt.show()

# %% [markdown]
# ### Fit a simple regression model to the generated training data

# %%
from sklearn.linear_model import LinearRegression

X = np.array(generated_training_data)[:,:2]
y = np.array(generated_training_data)[:,2]

meta_regressor_pipeline = Pipeline([
    ('scaling', StandardScaler()), 
    ('learner', LinearRegression())
])

meta_regressor = meta_regressor_pipeline.fit(X, y)

# %% [markdown]
# ### Evaluate regression model in predicting effects of errors in the unseen target data

# %%
predicted_scores = []
true_scores = []

for num_columns_affected in tqdm(range(1, 5)):
    for fraction_of_values_to_delete in [0.05, 0.25, 0.5, 0.75, 0.99]:    
        for _ in range(0, 100):        
            columns_affected = np.random.choice(categorical_columns, num_columns_affected)        

            corrupted_target_data = delete_cells(target_data, fraction_of_values_to_delete, columns_affected)

            predictions = model.predict_proba(corrupted_target_data)
            
            entropy_good = entropy(np.transpose(predictions)[0])
            entropy_bad = entropy(np.transpose(predictions)[1])           

            score_on_corrupted_target_data = accuracy_score(y_target, model.predict(corrupted_target_data))
            predicted_score_on_corrupted_target_data = meta_regressor.predict([[entropy_good, entropy_bad]])
            
            predicted_scores.append(predicted_score_on_corrupted_target_data)
            true_scores.append(score_on_corrupted_target_data)
# Out:
# 100%|██████████| 4/4 [02:07<00:00, 31.73s/it]

# %%
from scipy import stats

gradient, intercept, _, _, _ = stats.linregress(np.array(true_scores).flatten(), np.array(predicted_scores).flatten())

plt.scatter(true_scores, predicted_scores, alpha=0.05)

x1 = np.linspace(0.6, 0.8, 100)
plt.plot(x1, gradient * x1 + intercept, '-')

plt.xlabel("true accuracy on corrupted target data")
plt.ylabel("predicted accuracy on corrupted target data")
plt.plot([0.6, 0.8], [0.6, 0.8], color='black', alpha=0.5)
plt.show()

# %%
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import mean_absolute_error as MAE

score_on_corrupted_target_data = MAE(true_scores, predicted_scores)

print("score on corrupted target data: ", score_on_corrupted_target_data)
# Out:
# score on corrupted target data:  0.010866249921336123

# %%
plt.plot(range(len(predicted_scores)), predicted_scores, 'go')
plt.plot(range(len(true_scores)), true_scores, 'r^')
plt.show()
