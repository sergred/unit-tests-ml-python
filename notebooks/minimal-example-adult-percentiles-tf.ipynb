# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load dataset, resample to have balanced classes

# %%
complete_data = pd.read_csv('../resources/data/adult/adult.csv')

rich = complete_data[complete_data['class'] == '>50K']
not_rich = complete_data[complete_data['class'] != '>50K'].sample(len(rich))

data = pd.concat([rich, not_rich])

# %%
data
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 14      40           Private  121772     Assoc-voc             11
# 19      43  Self-emp-not-inc  292175       Masters             14
# 20      40           Private  193524     Doctorate             16
# 25      56         Local-gov  216851     Bachelors             13
# 27      54                 ?  180211  Some-college             10
# 38      31           Private   84154  Some-college             10
# 45      57       Federal-gov  337895     Bachelors             13
# 52      47           Private   51835   Prof-school             15
# 53      50       Federal-gov  251585     Bachelors             13
# 55      43           Private  237993  Some-college             10
# 63      42           Private  116632     Doctorate             16
# 67      53           Private  169846       HS-grad              9
# 68      49      Self-emp-inc  191681  Some-college             10
# 72      29  Self-emp-not-inc  162298     Bachelors             13
# 84      44           Private  343591       HS-grad              9
# 86      49         Local-gov  268234       HS-grad              9
# 89      43       Federal-gov  410867     Doctorate             16
# 94      34         Local-gov  226296     Bachelors             13
# 96      48  Self-emp-not-inc  191277     Doctorate             16
# 97      37           Private  202683  Some-college             10
# 100     76           Private  124191       Masters             14
# 101     44           Private  198282     Bachelors             13
# 105     32      Self-emp-inc  317660       HS-grad              9
# 111     38           Private   65324   Prof-school             15
# 112     56  Self-emp-not-inc  335605       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 11636   37           Private  215392     Bachelors             13
# 2558    58         State-gov  110517     Doctorate             16
# 22151   20           Private  278155  Some-college             10
# 23838   32           Private  262153       HS-grad              9
# 3840    29           Private   56630     Assoc-voc             11
# 28947   38      Self-emp-inc  379485    Assoc-acdm             12
# 17770   39  Self-emp-not-inc  160808  Some-college             10
# 6502    33           Private  213226       HS-grad              9
# 15093   25           Private  208117     Bachelors             13
# 9600    29      Self-emp-inc   87745  Some-college             10
# 8555    69           Private  512992          11th              7
# 10930   59           Private  186385          10th              6
# 7567    22           Private  141698          10th              6
# 88      30           Private   54334           9th              5
# 11270   25           Private  121102    Assoc-acdm             12
# 21035   25           Private  221757       HS-grad              9
# 2807    44           Private  174491       HS-grad              9
# 20197   30           Private  178841     Bachelors             13
# 20604   23           Private  189924  Some-college             10
# 30296   22           Private   48988  Some-college             10
# 14166   55           Private   23789       HS-grad              9
# 12351   22                 ?   34616  Some-college             10
# 22376   29           Private  161857       HS-grad              9
# 11698   17           Private  150262          11th              7
# 27013   26           Private  417941     Bachelors             13
# 9376    42           Private  194636       HS-grad              9
# 13601   24           Private   89154           9th              5
# 12260   31           Private  166343       HS-grad              9
# 376     33           Private  267404       HS-grad              9
# 26135   28         State-gov  200775       Masters             14
#
#               marital_status         occupation    relationship  \
# 7         Married-civ-spouse    Exec-managerial         Husband
# 8              Never-married     Prof-specialty   Not-in-family
# 9         Married-civ-spouse    Exec-managerial         Husband
# 10        Married-civ-spouse    Exec-managerial         Husband
# 11        Married-civ-spouse     Prof-specialty         Husband
# 14        Married-civ-spouse       Craft-repair         Husband
# 19                  Divorced    Exec-managerial       Unmarried
# 20        Married-civ-spouse     Prof-specialty         Husband
# 25        Married-civ-spouse       Tech-support         Husband
# 27        Married-civ-spouse                  ?         Husband
# 38        Married-civ-spouse              Sales         Husband
# 45        Married-civ-spouse     Prof-specialty         Husband
# 52        Married-civ-spouse     Prof-specialty            Wife
# 53                  Divorced    Exec-managerial   Not-in-family
# 55        Married-civ-spouse       Tech-support         Husband
# 63        Married-civ-spouse     Prof-specialty         Husband
# 67        Married-civ-spouse       Adm-clerical            Wife
# 68        Married-civ-spouse    Exec-managerial         Husband
# 72        Married-civ-spouse              Sales         Husband
# 84                  Divorced       Craft-repair   Not-in-family
# 86        Married-civ-spouse    Protective-serv         Husband
# 89             Never-married     Prof-specialty   Not-in-family
# 94        Married-civ-spouse    Protective-serv         Husband
# 96        Married-civ-spouse     Prof-specialty         Husband
# 97        Married-civ-spouse              Sales         Husband
# 100       Married-civ-spouse    Exec-managerial         Husband
# 101       Married-civ-spouse    Exec-managerial         Husband
# 105       Married-civ-spouse       Craft-repair         Husband
# 111       Married-civ-spouse     Prof-specialty         Husband
# 112       Married-civ-spouse      Other-service         Husband
# ...                      ...                ...             ...
# 11636               Divorced     Prof-specialty   Not-in-family
# 2558      Married-civ-spouse     Prof-specialty         Husband
# 22151          Never-married       Adm-clerical       Own-child
# 23838               Divorced       Craft-repair       Unmarried
# 3840      Married-civ-spouse       Adm-clerical         Husband
# 28947               Divorced    Exec-managerial       Unmarried
# 17770     Married-civ-spouse      Other-service         Husband
# 6502                Divorced              Sales   Not-in-family
# 15093          Never-married     Prof-specialty  Other-relative
# 9600           Never-married    Exec-managerial   Not-in-family
# 8555      Married-civ-spouse     Prof-specialty         Husband
# 10930     Married-civ-spouse  Machine-op-inspct         Husband
# 7567           Never-married       Craft-repair       Unmarried
# 88             Never-married              Sales   Not-in-family
# 11270          Never-married       Tech-support   Not-in-family
# 21035     Married-civ-spouse  Machine-op-inspct         Husband
# 2807                 Widowed      Other-service       Unmarried
# 20197          Never-married    Exec-managerial   Not-in-family
# 20604          Never-married      Other-service       Own-child
# 30296          Never-married   Transport-moving   Not-in-family
# 14166               Divorced    Exec-managerial   Not-in-family
# 12351          Never-married                  ?       Own-child
# 22376  Married-spouse-absent      Other-service   Not-in-family
# 11698          Never-married              Sales       Own-child
# 27013          Never-married    Exec-managerial   Not-in-family
# 9376      Married-civ-spouse              Sales         Husband
# 13601          Never-married      Other-service   Not-in-family
# 12260          Never-married  Machine-op-inspct       Own-child
# 376       Married-civ-spouse       Craft-repair            Wife
# 26135     Married-civ-spouse    Exec-managerial            Wife
#
#                      race     sex  capital_gain  capital_loss  hours_per_week  \
# 7                   White    Male             0             0              45
# 8                   White  Female         14084             0              50
# 9                   White    Male          5178             0              40
# 10                  Black    Male             0             0              80
# 11     Asian-Pac-Islander    Male             0             0              40
# 14     Asian-Pac-Islander    Male             0             0              40
# 19                  White  Female             0             0              45
# 20                  White    Male             0             0              60
# 25                  White    Male             0             0              40
# 27     Asian-Pac-Islander    Male             0             0              60
# 38                  White    Male             0             0              38
# 45                  Black    Male             0             0              40
# 52                  White  Female             0          1902              60
# 53                  White    Male             0             0              55
# 55                  White    Male             0             0              40
# 63                  White    Male             0             0              45
# 67                  White  Female             0             0              40
# 68                  White    Male             0             0              50
# 72                  White    Male             0             0              70
# 84                  White  Female         14344             0              40
# 86                  White    Male             0             0              40
# 89                  White  Female             0             0              50
# 94                  White    Male             0             0              40
# 96                  White    Male             0          1902              60
# 97                  White    Male             0             0              48
# 100                 White    Male             0             0              40
# 101                 White    Male         15024             0              60
# 105                 White    Male          7688             0              40
# 111                 White    Male             0             0              40
# 112                 White    Male             0          1887              50
# ...                   ...     ...           ...           ...             ...
# 11636               White  Female             0             0              40
# 2558   Asian-Pac-Islander    Male          4064             0              40
# 22151               White    Male             0             0              40
# 23838               White    Male             0             0              35
# 3840                White    Male             0             0              40
# 28947               White    Male             0             0              45
# 17770               Black    Male             0             0              40
# 6502                White    Male             0             0              50
# 15093               White    Male             0             0              40
# 9600                White    Male             0             0              60
# 8555                Black    Male             0             0              45
# 10930               White    Male             0             0              40
# 7567                White    Male             0             0              40
# 88                  White    Male             0             0              40
# 11270               White  Female             0          2001              30
# 21035               White    Male             0             0              40
# 2807                Black  Female             0             0              30
# 20197               White  Female             0             0              40
# 20604               White  Female             0             0              40
# 30296               White    Male             0             0              40
# 14166               White  Female             0             0              40
# 12351               White  Female             0             0              20
# 22376               Other  Female             0             0              40
# 11698               White  Female             0             0              20
# 27013               White  Female             0             0              40
# 9376                White    Male             0             0              40
# 13601               White    Male             0             0              40
# 12260               Black    Male             0             0              50
# 376                 White  Female             0             0              40
# 26135               White  Female             0             0              40
#
#       native_country  class
# 7      United-States   >50K
# 8      United-States   >50K
# 9      United-States   >50K
# 10     United-States   >50K
# 11             India   >50K
# 14                 ?   >50K
# 19     United-States   >50K
# 20     United-States   >50K
# 25     United-States   >50K
# 27             South   >50K
# 38                 ?   >50K
# 45     United-States   >50K
# 52          Honduras   >50K
# 53     United-States   >50K
# 55     United-States   >50K
# 63     United-States   >50K
# 67     United-States   >50K
# 68     United-States   >50K
# 72     United-States   >50K
# 84     United-States   >50K
# 86     United-States   >50K
# 89     United-States   >50K
# 94     United-States   >50K
# 96     United-States   >50K
# 97     United-States   >50K
# 100    United-States   >50K
# 101    United-States   >50K
# 105    United-States   >50K
# 111    United-States   >50K
# 112           Canada   >50K
# ...              ...    ...
# 11636  United-States  <=50K
# 2558           India  <=50K
# 22151  United-States  <=50K
# 23838  United-States  <=50K
# 3840   United-States  <=50K
# 28947  United-States  <=50K
# 17770  United-States  <=50K
# 6502   United-States  <=50K
# 15093  United-States  <=50K
# 9600   United-States  <=50K
# 8555   United-States  <=50K
# 10930  United-States  <=50K
# 7567   United-States  <=50K
# 88     United-States  <=50K
# 11270  United-States  <=50K
# 21035  United-States  <=50K
# 2807   United-States  <=50K
# 20197  United-States  <=50K
# 20604  United-States  <=50K
# 30296  United-States  <=50K
# 14166  United-States  <=50K
# 12351  United-States  <=50K
# 22376       Columbia  <=50K
# 11698  United-States  <=50K
# 27013  United-States  <=50K
# 9376   United-States  <=50K
# 13601    El-Salvador  <=50K
# 12260              ?  <=50K
# 376    United-States  <=50K
# 26135  United-States  <=50K
#
# [15682 rows x 15 columns]

# %% [markdown]
# ### Train a DNN model

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
from tensorflow import keras

import warnings
warnings.filterwarnings('ignore')

def labels_from(df):
    return np.array(df['class'] == '>50K')

train_data, heldout_data = train_test_split(data, test_size=0.2)
test_data, target_data = train_test_split(heldout_data, test_size=0.5)

y_train = labels_from(train_data)
y_test = labels_from(test_data)
y_target = labels_from(target_data)

categorical_columns = ['workclass', 'occupation', 'marital_status', 'education']

numeric_columns = ['hours_per_week', 'age']

feature_transformation = ColumnTransformer(transformers=[
    ('categorical_features', OneHotEncoder(handle_unknown='ignore'), categorical_columns),
    ('scaled_numeric', StandardScaler(), numeric_columns)
])

nn = keras.Sequential([
    keras.layers.Dense(4, activation=tf.nn.relu),
    keras.layers.Dense(2, activation=tf.nn.softmax)
])

nn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

featurizer = feature_transformation.fit(train_data)

nn.fit(featurizer.transform(train_data).todense(), y_train, epochs=100)
# Out:
# Epoch 1/100
# 12545/12545 [==============================] - 0s 30us/step - loss: 0.5921 - acc: 0.6861
# Epoch 2/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4496 - acc: 0.7892
# Epoch 3/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4329 - acc: 0.7974
# Epoch 4/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4275 - acc: 0.8014
# Epoch 5/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4245 - acc: 0.8041
# Epoch 6/100
# 12545/12545 [==============================] - 0s 21us/step - loss: 0.4222 - acc: 0.8034
# Epoch 7/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4205 - acc: 0.8053
# Epoch 8/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4189 - acc: 0.8047
# Epoch 9/100
# 12545/12545 [==============================] - 0s 21us/step - loss: 0.4182 - acc: 0.8042
# Epoch 10/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4174 - acc: 0.8053
# Epoch 11/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4169 - acc: 0.8061
# Epoch 12/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4163 - acc: 0.8065
# Epoch 13/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4156 - acc: 0.8063
# Epoch 14/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4151 - acc: 0.8046
# Epoch 15/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4150 - acc: 0.8059
# Epoch 16/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4145 - acc: 0.8067
# Epoch 17/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4140 - acc: 0.8079
# Epoch 18/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4138 - acc: 0.8060
# Epoch 19/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4134 - acc: 0.8075
# Epoch 20/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4134 - acc: 0.8078
# Epoch 21/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4133 - acc: 0.8067
# Epoch 22/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4131 - acc: 0.8079
# Epoch 23/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4128 - acc: 0.8073
# Epoch 24/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4127 - acc: 0.8083
# Epoch 25/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4125 - acc: 0.8066
# Epoch 26/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4127 - acc: 0.8073
# Epoch 27/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4122 - acc: 0.8078
# Epoch 28/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4120 - acc: 0.8071
# Epoch 29/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4121 - acc: 0.8084
# Epoch 30/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4120 - acc: 0.8076
# Epoch 31/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4116 - acc: 0.8081
# Epoch 32/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4115 - acc: 0.8084
# Epoch 33/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4113 - acc: 0.8092
# Epoch 34/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4112 - acc: 0.8085
# Epoch 35/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4114 - acc: 0.8081
# Epoch 36/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4114 - acc: 0.8081
# Epoch 37/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4110 - acc: 0.8080
# Epoch 38/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4109 - acc: 0.8084
# Epoch 39/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4110 - acc: 0.8066
# Epoch 40/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4108 - acc: 0.8077
# Epoch 41/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4106 - acc: 0.8082
# Epoch 42/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4103 - acc: 0.8098
# Epoch 43/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4105 - acc: 0.8086
# Epoch 44/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4105 - acc: 0.8088
# Epoch 45/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4104 - acc: 0.8095
# Epoch 46/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4101 - acc: 0.8081
# Epoch 47/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4101 - acc: 0.8094
# Epoch 48/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4101 - acc: 0.8077
# Epoch 49/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4100 - acc: 0.8081
# Epoch 50/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4096 - acc: 0.8087
# Epoch 51/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4099 - acc: 0.8088
# Epoch 52/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4098 - acc: 0.8073
# Epoch 53/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4097 - acc: 0.8081
# Epoch 54/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4098 - acc: 0.8098
# Epoch 55/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4097 - acc: 0.8083
# Epoch 56/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4094 - acc: 0.8088
# Epoch 57/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4094 - acc: 0.8091
# Epoch 58/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4096 - acc: 0.8086
# Epoch 59/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4091 - acc: 0.8095
# Epoch 60/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4092 - acc: 0.8089
# Epoch 61/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4093 - acc: 0.8086
# Epoch 62/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4090 - acc: 0.8105
# Epoch 63/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4096 - acc: 0.8092
# Epoch 64/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4088 - acc: 0.8096
# Epoch 65/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4089 - acc: 0.8089
# Epoch 66/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4089 - acc: 0.8100
# Epoch 67/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4089 - acc: 0.8103
# Epoch 68/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4087 - acc: 0.8108
# Epoch 69/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4089 - acc: 0.8099
# Epoch 70/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4084 - acc: 0.8102
# Epoch 71/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4087 - acc: 0.8111
# Epoch 72/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4080 - acc: 0.8099
# Epoch 73/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4087 - acc: 0.8098
# Epoch 74/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4085 - acc: 0.8092
# Epoch 75/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4083 - acc: 0.8106
# Epoch 76/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4083 - acc: 0.8093
# Epoch 77/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4082 - acc: 0.8098
# Epoch 78/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4084 - acc: 0.8100
# Epoch 79/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4082 - acc: 0.8108
# Epoch 80/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4083 - acc: 0.8096
# Epoch 81/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4082 - acc: 0.8106
# Epoch 82/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4081 - acc: 0.8090
# Epoch 83/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4083 - acc: 0.8108
# Epoch 84/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4082 - acc: 0.8103
# Epoch 85/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4084 - acc: 0.8106
# Epoch 86/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4082 - acc: 0.8109
# Epoch 87/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4082 - acc: 0.8102
# Epoch 88/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4080 - acc: 0.8104
# Epoch 89/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4080 - acc: 0.8099
# Epoch 90/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4080 - acc: 0.8099
# Epoch 91/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4078 - acc: 0.8106
# Epoch 92/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4082 - acc: 0.8101
# Epoch 93/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4079 - acc: 0.8095
# Epoch 94/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4081 - acc: 0.8102
# Epoch 95/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4076 - acc: 0.8119
# Epoch 96/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4079 - acc: 0.8106
# Epoch 97/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4079 - acc: 0.8100
# Epoch 98/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4078 - acc: 0.8100
# Epoch 99/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4075 - acc: 0.8118
# Epoch 100/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4077 - acc: 0.8109

# %%
class ModelWithFeaturization:

    def __init__(self, nn, featurizer):
        self.nn = nn
        self.featurizer = featurizer
        
    def predict(self, df):
        return [np.argmax(p) for p in self.nn.predict(self.featurizer.transform(df).todense())]
    
    def predict_proba(self, df):
        return self.nn.predict(self.featurizer.transform(df).todense())
    
model = ModelWithFeaturization(nn, featurizer)

# %%
score_on_train_data = accuracy_score(y_train, model.predict(train_data))
score_on_noncorrupted_test_data = accuracy_score(y_test, model.predict(test_data))
score_on_noncorrupted_target_data = accuracy_score(y_target, model.predict(target_data))

print("score on train data: ", score_on_train_data)
print("score on test data: ", score_on_noncorrupted_test_data)
print("score on target data: ", score_on_noncorrupted_target_data)
# Out:
# score on train data:  0.8112395376644082
# score on test data:  0.8182397959183674
# score on target data:  0.8253664754620778

# %% [markdown]
# ### Introduce errors (missing values) into unseen test data, record resulting class probability entropies and accuracy score as inputs for the meta regressor

# %%
def percentiles_of_probas(predictions):
    probs_class_a = np.transpose(predictions)[0]
    probs_class_b = np.transpose(predictions)[1]
    features_a = np.percentile(probs_class_a, np.arange(0,101,5))
    features_b = np.percentile(probs_class_b, np.arange(0,101,5))  
    return np.concatenate((features_a, features_b), axis=0) 

num_features = 42

# %%
import random
from scipy.stats import entropy
from tqdm import tqdm

def delete_cells(df, fraction, columns):
    # we operate on a copy of the data
    corrupted_df = df.copy(deep=True)
    
    row_indexes = [row for row in range(corrupted_df.shape[0])]
    # pick random examples
    num_rows_to_pick = int(round(fraction * len(row_indexes)))
    for random_row_index in random.sample(row_indexes, num_rows_to_pick):           
        # delete all specified values in the target columns
        for column in columns:
            column_index = df.columns.get_loc(column)
            corrupted_df.iat[random_row_index, column_index] = 'n/a'
    
    return corrupted_df

generated_training_data = []

for num_columns_affected in tqdm(range(1, 5)):
    for fraction_of_values_to_delete in [0.0, 0.05, 0.25, 0.5, 0.75, 0.99]:    
        for _ in range(0, 100):        
            columns_affected = np.random.choice(categorical_columns, num_columns_affected)        

            corrupted_test_data = delete_cells(test_data, fraction_of_values_to_delete, columns_affected)

            predictions = model.predict_proba(corrupted_test_data)                     
            features = percentiles_of_probas(predictions)
                                       
            score_on_corrupted_test_data = accuracy_score(y_test, model.predict(corrupted_test_data))                
                
            example = np.concatenate((features, [score_on_corrupted_test_data]), axis=0)                                       
            
            generated_training_data.append(example)
# Out:
# 100%|██████████| 4/4 [01:34<00:00, 23.68s/it]

# %% [markdown]
# ### Fit a regression model to the generated training data

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor

X = np.array(generated_training_data)[:,:num_features]
y = np.array(generated_training_data)[:,num_features]

param_grid = {
    'learner__n_estimators': np.arange(5,20,5),
    'learner__criterion': ['mae']
}

meta_regressor_pipeline = Pipeline([
    ('scaling', StandardScaler()), 
    ('learner', RandomForestRegressor())
])

meta_regressor = GridSearchCV(meta_regressor_pipeline, param_grid, scoring='neg_mean_absolute_error').fit(X, y)

# %% [markdown]
# ### Evaluate regression model in predicting effects of errors in the unseen target data

# %%
predicted_scores = []
true_scores = []

for num_columns_affected in tqdm(range(1, 5)):
    for fraction_of_values_to_delete in [0.05, 0.25, 0.5, 0.75, 0.99]:    
        for _ in range(0, 100):        
            columns_affected = np.random.choice(categorical_columns, num_columns_affected)        

            corrupted_target_data = delete_cells(target_data, fraction_of_values_to_delete, columns_affected)

            predictions = model.predict_proba(corrupted_target_data)
            features = percentiles_of_probas(predictions)                

            score_on_corrupted_target_data = accuracy_score(y_target, model.predict(corrupted_target_data))
            predicted_score_on_corrupted_target_data = meta_regressor.predict([features])
            
            predicted_scores.append(predicted_score_on_corrupted_target_data)
            true_scores.append(score_on_corrupted_target_data)
# Out:
# 100%|██████████| 4/4 [01:25<00:00, 21.33s/it]

# %%
import scipy.stats

plt.plot([0,1], [0, 1], '-', color='grey', alpha=0.5)

gradient, intercept, _, _, _ = scipy.stats.linregress(np.array(true_scores).flatten(), np.array(predicted_scores).flatten())
x1 = np.linspace(0.6, 0.82, 100)
plt.plot(x1, gradient * x1 + intercept, '--')

plt.scatter(true_scores, predicted_scores, alpha=0.05)

plt.xlabel("true accuracy", fontsize=16)
plt.ylabel("predicted accuracy", fontsize=16)

plt.xlim((0.5, 0.9))
plt.ylim((0.5, 0.9))         

from sklearn.metrics import mean_squared_error, mean_absolute_error

mse = mean_squared_error(true_scores, predicted_scores)
mae = mean_absolute_error(true_scores, predicted_scores)

plt.text(0.68, 0.53, "MSE %.5f   MAE %.4f" % (mse, mae), fontsize=12, 
         bbox=dict(facecolor='none', edgecolor='black', pad=10.0))

plt.legend(['perfect', 'prediction'], fontsize=12)
plt.gcf().set_size_inches(6, 5)
plt.gcf().savefig('figures/adult-tf.pdf', dpi=300)
plt.show()
