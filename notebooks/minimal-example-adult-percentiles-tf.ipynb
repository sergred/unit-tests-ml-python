# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load dataset, resample to have balanced classes

# %%
complete_data = pd.read_csv('../resources/data/adult/adult.csv')

rich = complete_data[complete_data['class'] == '>50K']
not_rich = complete_data[complete_data['class'] != '>50K'].sample(len(rich))

data = pd.concat([rich, not_rich])

# %%
data
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 14      40           Private  121772     Assoc-voc             11
# 19      43  Self-emp-not-inc  292175       Masters             14
# 20      40           Private  193524     Doctorate             16
# 25      56         Local-gov  216851     Bachelors             13
# 27      54                 ?  180211  Some-college             10
# 38      31           Private   84154  Some-college             10
# 45      57       Federal-gov  337895     Bachelors             13
# 52      47           Private   51835   Prof-school             15
# 53      50       Federal-gov  251585     Bachelors             13
# 55      43           Private  237993  Some-college             10
# 63      42           Private  116632     Doctorate             16
# 67      53           Private  169846       HS-grad              9
# 68      49      Self-emp-inc  191681  Some-college             10
# 72      29  Self-emp-not-inc  162298     Bachelors             13
# 84      44           Private  343591       HS-grad              9
# 86      49         Local-gov  268234       HS-grad              9
# 89      43       Federal-gov  410867     Doctorate             16
# 94      34         Local-gov  226296     Bachelors             13
# 96      48  Self-emp-not-inc  191277     Doctorate             16
# 97      37           Private  202683  Some-college             10
# 100     76           Private  124191       Masters             14
# 101     44           Private  198282     Bachelors             13
# 105     32      Self-emp-inc  317660       HS-grad              9
# 111     38           Private   65324   Prof-school             15
# 112     56  Self-emp-not-inc  335605       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 8277    43           Private  209149       HS-grad              9
# 24006   29         State-gov  214284       Masters             14
# 4436    39           Private  185099       HS-grad              9
# 7455    23           Private  528616       5th-6th              3
# 31341   29           Private  342989       HS-grad              9
# 16095   35           Private  283237       HS-grad              9
# 12671   21           Private  219086       HS-grad              9
# 13378   37         Local-gov   89491       Masters             14
# 12487   34           Private  119153          11th              7
# 28646   41  Self-emp-not-inc  193459  Some-college             10
# 589     57      Self-emp-inc  103948     Bachelors             13
# 16108   74           Private  194312           9th              5
# 7877    24           Private  357028  Some-college             10
# 4364    29           Private  355569     Assoc-voc             11
# 17746   27           Private  160786          11th              7
# 16860   24           Private  109053       HS-grad              9
# 6908    35           Private  108293  Some-college             10
# 14620   56  Self-emp-not-inc   84774    Assoc-acdm             12
# 4012    35           Private  227571       7th-8th              4
# 4065    66           Private  340734       HS-grad              9
# 25187   36       Federal-gov  203836  Some-college             10
# 18720   60                 ?   41517          11th              7
# 29490   29           Private  239753       HS-grad              9
# 6098    58           Private  117477       HS-grad              9
# 21636   51           Private   68882       1st-4th              2
# 16517   31           Private  198069       HS-grad              9
# 8264    49           Private  211005  Some-college             10
# 14552   56           Private  134195       Masters             14
# 30267   19           Private  229431  Some-college             10
# 23359   24           Private  424494     Bachelors             13
#
#               marital_status         occupation    relationship  \
# 7         Married-civ-spouse    Exec-managerial         Husband
# 8              Never-married     Prof-specialty   Not-in-family
# 9         Married-civ-spouse    Exec-managerial         Husband
# 10        Married-civ-spouse    Exec-managerial         Husband
# 11        Married-civ-spouse     Prof-specialty         Husband
# 14        Married-civ-spouse       Craft-repair         Husband
# 19                  Divorced    Exec-managerial       Unmarried
# 20        Married-civ-spouse     Prof-specialty         Husband
# 25        Married-civ-spouse       Tech-support         Husband
# 27        Married-civ-spouse                  ?         Husband
# 38        Married-civ-spouse              Sales         Husband
# 45        Married-civ-spouse     Prof-specialty         Husband
# 52        Married-civ-spouse     Prof-specialty            Wife
# 53                  Divorced    Exec-managerial   Not-in-family
# 55        Married-civ-spouse       Tech-support         Husband
# 63        Married-civ-spouse     Prof-specialty         Husband
# 67        Married-civ-spouse       Adm-clerical            Wife
# 68        Married-civ-spouse    Exec-managerial         Husband
# 72        Married-civ-spouse              Sales         Husband
# 84                  Divorced       Craft-repair   Not-in-family
# 86        Married-civ-spouse    Protective-serv         Husband
# 89             Never-married     Prof-specialty   Not-in-family
# 94        Married-civ-spouse    Protective-serv         Husband
# 96        Married-civ-spouse     Prof-specialty         Husband
# 97        Married-civ-spouse              Sales         Husband
# 100       Married-civ-spouse    Exec-managerial         Husband
# 101       Married-civ-spouse    Exec-managerial         Husband
# 105       Married-civ-spouse       Craft-repair         Husband
# 111       Married-civ-spouse     Prof-specialty         Husband
# 112       Married-civ-spouse      Other-service         Husband
# ...                      ...                ...             ...
# 8277                Divorced      Other-service   Not-in-family
# 24006          Never-married     Prof-specialty       Unmarried
# 4436      Married-civ-spouse    Exec-managerial         Husband
# 7455      Married-civ-spouse      Other-service         Husband
# 31341          Never-married       Adm-clerical       Own-child
# 16095          Never-married  Machine-op-inspct       Own-child
# 12671          Never-married      Other-service       Own-child
# 13378               Divorced    Exec-managerial   Not-in-family
# 12487     Married-civ-spouse   Transport-moving         Husband
# 28646     Married-civ-spouse       Craft-repair         Husband
# 589                 Divorced     Prof-specialty   Not-in-family
# 16108                Widowed       Craft-repair   Not-in-family
# 7877           Never-married    Exec-managerial       Own-child
# 4364           Never-married    Exec-managerial       Unmarried
# 17746              Separated       Craft-repair   Not-in-family
# 16860          Never-married      Other-service  Other-relative
# 6908           Never-married       Adm-clerical       Own-child
# 14620     Married-civ-spouse    Farming-fishing            Wife
# 4012      Married-civ-spouse  Handlers-cleaners         Husband
# 4065      Married-civ-spouse              Sales         Husband
# 25187     Married-civ-spouse  Handlers-cleaners         Husband
# 18720  Married-spouse-absent                  ?       Unmarried
# 29490     Married-civ-spouse       Adm-clerical            Wife
# 6098                Divorced       Adm-clerical       Unmarried
# 21636                Widowed      Other-service       Unmarried
# 16517          Never-married      Other-service       Own-child
# 8264      Married-civ-spouse  Machine-op-inspct         Husband
# 14552          Never-married              Sales   Not-in-family
# 30267          Never-married     Prof-specialty       Own-child
# 23359     Married-civ-spouse     Prof-specialty         Husband
#
#                      race     sex  capital_gain  capital_loss  hours_per_week  \
# 7                   White    Male             0             0              45
# 8                   White  Female         14084             0              50
# 9                   White    Male          5178             0              40
# 10                  Black    Male             0             0              80
# 11     Asian-Pac-Islander    Male             0             0              40
# 14     Asian-Pac-Islander    Male             0             0              40
# 19                  White  Female             0             0              45
# 20                  White    Male             0             0              60
# 25                  White    Male             0             0              40
# 27     Asian-Pac-Islander    Male             0             0              60
# 38                  White    Male             0             0              38
# 45                  Black    Male             0             0              40
# 52                  White  Female             0          1902              60
# 53                  White    Male             0             0              55
# 55                  White    Male             0             0              40
# 63                  White    Male             0             0              45
# 67                  White  Female             0             0              40
# 68                  White    Male             0             0              50
# 72                  White    Male             0             0              70
# 84                  White  Female         14344             0              40
# 86                  White    Male             0             0              40
# 89                  White  Female             0             0              50
# 94                  White    Male             0             0              40
# 96                  White    Male             0          1902              60
# 97                  White    Male             0             0              48
# 100                 White    Male             0             0              40
# 101                 White    Male         15024             0              60
# 105                 White    Male          7688             0              40
# 111                 White    Male             0             0              40
# 112                 White    Male             0          1887              50
# ...                   ...     ...           ...           ...             ...
# 8277                White  Female             0             0              35
# 24006  Asian-Pac-Islander  Female             0             0              20
# 4436                White    Male             0             0              40
# 7455                White    Male             0             0              40
# 31341               White  Female             0             0              40
# 16095               White    Male             0             0              40
# 12671               White    Male             0             0              35
# 13378               White  Female             0             0              40
# 12487               White    Male             0             0              50
# 28646               White    Male             0             0              50
# 589                 White    Male             0             0              80
# 16108               White    Male             0             0              10
# 7877                White    Male             0             0              40
# 4364                White  Female             0             0              50
# 17746               White    Male             0             0              45
# 16860               White    Male             0             0              25
# 6908                White  Female             0          2205              40
# 14620               White  Female             0             0              40
# 4012                White    Male             0             0              40
# 4065                White    Male             0             0              40
# 25187               White    Male             0             0              50
# 18720               Black  Female             0             0              20
# 29490               White  Female             0          2057              20
# 6098                Black  Female             0             0              36
# 21636               White  Female             0             0              35
# 16517               White    Male             0             0              24
# 8264                Black    Male             0             0              60
# 14552               White    Male             0             0              50
# 30267               White    Male             0             0              11
# 23359               White    Male             0             0              30
#
#       native_country  class
# 7      United-States   >50K
# 8      United-States   >50K
# 9      United-States   >50K
# 10     United-States   >50K
# 11             India   >50K
# 14                 ?   >50K
# 19     United-States   >50K
# 20     United-States   >50K
# 25     United-States   >50K
# 27             South   >50K
# 38                 ?   >50K
# 45     United-States   >50K
# 52          Honduras   >50K
# 53     United-States   >50K
# 55     United-States   >50K
# 63     United-States   >50K
# 67     United-States   >50K
# 68     United-States   >50K
# 72     United-States   >50K
# 84     United-States   >50K
# 86     United-States   >50K
# 89     United-States   >50K
# 94     United-States   >50K
# 96     United-States   >50K
# 97     United-States   >50K
# 100    United-States   >50K
# 101    United-States   >50K
# 105    United-States   >50K
# 111    United-States   >50K
# 112           Canada   >50K
# ...              ...    ...
# 8277   United-States  <=50K
# 24006         Taiwan  <=50K
# 4436   United-States  <=50K
# 7455          Mexico  <=50K
# 31341  United-States  <=50K
# 16095  United-States  <=50K
# 12671  United-States  <=50K
# 13378  United-States  <=50K
# 12487  United-States  <=50K
# 28646  United-States  <=50K
# 589    United-States  <=50K
# 16108              ?  <=50K
# 7877   United-States  <=50K
# 4364   United-States  <=50K
# 17746        Germany  <=50K
# 16860  United-States  <=50K
# 6908   United-States  <=50K
# 14620  United-States  <=50K
# 4012          Mexico  <=50K
# 4065   United-States  <=50K
# 25187  United-States  <=50K
# 18720  United-States  <=50K
# 29490  United-States  <=50K
# 6098   United-States  <=50K
# 21636       Portugal  <=50K
# 16517  United-States  <=50K
# 8264   United-States  <=50K
# 14552  United-States  <=50K
# 30267  United-States  <=50K
# 23359  United-States  <=50K
#
# [15682 rows x 15 columns]

# %% [markdown]
# ### Train a logistic regression model, using grid search and k-fold cross-validation

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
from tensorflow import keras

import warnings
warnings.filterwarnings('ignore')

def labels_from(df):
    return np.array(df['class'] == '>50K')

train_data, heldout_data = train_test_split(data, test_size=0.2)
test_data, target_data = train_test_split(heldout_data, test_size=0.5)

y_train = labels_from(train_data)
y_test = labels_from(test_data)
y_target = labels_from(target_data)

categorical_columns = ['workclass', 'occupation', 'marital_status', 'education']

numeric_columns = ['hours_per_week', 'age']

feature_transformation = ColumnTransformer(transformers=[
    ('categorical_features', OneHotEncoder(handle_unknown='ignore'), categorical_columns),
    ('scaled_numeric', StandardScaler(), numeric_columns)
])

nn = keras.Sequential([
    keras.layers.Dense(4, activation=tf.nn.relu),
    keras.layers.Dense(2, activation=tf.nn.softmax)
])

nn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

featurizer = feature_transformation.fit(train_data)

nn.fit(featurizer.transform(train_data).todense(), y_train, epochs=100)
# Out:
# Epoch 1/100
# 12545/12545 [==============================] - 0s 29us/step - loss: 0.5204 - acc: 0.7639
# Epoch 2/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4390 - acc: 0.7972
# Epoch 3/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4283 - acc: 0.8020
# Epoch 4/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4244 - acc: 0.8041
# Epoch 5/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4222 - acc: 0.8050
# Epoch 6/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4200 - acc: 0.8068
# Epoch 7/100
# 12545/12545 [==============================] - 0s 21us/step - loss: 0.4185 - acc: 0.8045
# Epoch 8/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4170 - acc: 0.8085
# Epoch 9/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4158 - acc: 0.8057
# Epoch 10/100
# 12545/12545 [==============================] - 0s 21us/step - loss: 0.4150 - acc: 0.8065
# Epoch 11/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4145 - acc: 0.8068
# Epoch 12/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4136 - acc: 0.8081
# Epoch 13/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4129 - acc: 0.8069
# Epoch 14/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4126 - acc: 0.8063
# Epoch 15/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4123 - acc: 0.8073
# Epoch 16/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4117 - acc: 0.8065
# Epoch 17/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4116 - acc: 0.8073
# Epoch 18/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4111 - acc: 0.8080
# Epoch 19/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4112 - acc: 0.8081
# Epoch 20/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4105 - acc: 0.8077
# Epoch 21/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4102 - acc: 0.8097
# Epoch 22/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4104 - acc: 0.8065
# Epoch 23/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4099 - acc: 0.8077
# Epoch 24/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4097 - acc: 0.8072
# Epoch 25/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4096 - acc: 0.8088
# Epoch 26/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4093 - acc: 0.8089
# Epoch 27/100
# 12545/12545 [==============================] - 0s 22us/step - loss: 0.4093 - acc: 0.8097
# Epoch 28/100
# 12545/12545 [==============================] - 0s 22us/step - loss: 0.4090 - acc: 0.8072
# Epoch 29/100
# 12545/12545 [==============================] - 0s 21us/step - loss: 0.4087 - acc: 0.8092
# Epoch 30/100
# 12545/12545 [==============================] - 0s 21us/step - loss: 0.4087 - acc: 0.8094
# Epoch 31/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4090 - acc: 0.8084
# Epoch 32/100
# 12545/12545 [==============================] - 0s 21us/step - loss: 0.4088 - acc: 0.8088
# Epoch 33/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4090 - acc: 0.8085
# Epoch 34/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4085 - acc: 0.8074
# Epoch 35/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4086 - acc: 0.8095
# Epoch 36/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4084 - acc: 0.8087
# Epoch 37/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4084 - acc: 0.8079
# Epoch 38/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4082 - acc: 0.8084
# Epoch 39/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4082 - acc: 0.8096
# Epoch 40/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4080 - acc: 0.8106
# Epoch 41/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4079 - acc: 0.8096
# Epoch 42/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4079 - acc: 0.8080
# Epoch 43/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4078 - acc: 0.8094
# Epoch 44/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4082 - acc: 0.8077
# Epoch 45/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4077 - acc: 0.8088
# Epoch 46/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4079 - acc: 0.8080
# Epoch 47/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4078 - acc: 0.8092
# Epoch 48/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4074 - acc: 0.8076
# Epoch 49/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4076 - acc: 0.8087
# Epoch 50/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4074 - acc: 0.8084
# Epoch 51/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4073 - acc: 0.8103
# Epoch 52/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4073 - acc: 0.8095
# Epoch 53/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4072 - acc: 0.8092
# Epoch 54/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4073 - acc: 0.8088
# Epoch 55/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4073 - acc: 0.8093
# Epoch 56/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4072 - acc: 0.8088
# Epoch 57/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4071 - acc: 0.8091
# Epoch 58/100
# 12545/12545 [==============================] - 0s 22us/step - loss: 0.4071 - acc: 0.8085
# Epoch 59/100
# 12545/12545 [==============================] - 0s 21us/step - loss: 0.4072 - acc: 0.8088
# Epoch 60/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4070 - acc: 0.8073
# Epoch 61/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4071 - acc: 0.8084
# Epoch 62/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4072 - acc: 0.8096
# Epoch 63/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4067 - acc: 0.8092
# Epoch 64/100
# 12545/12545 [==============================] - 0s 21us/step - loss: 0.4073 - acc: 0.8084
# Epoch 65/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4069 - acc: 0.8098
# Epoch 66/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4066 - acc: 0.8088
# Epoch 67/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4070 - acc: 0.8093
# Epoch 68/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4067 - acc: 0.8102
# Epoch 69/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4067 - acc: 0.8092
# Epoch 70/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4068 - acc: 0.8077
# Epoch 71/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4066 - acc: 0.8080
# Epoch 72/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4065 - acc: 0.8087
# Epoch 73/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4067 - acc: 0.8094
# Epoch 74/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4063 - acc: 0.8081
# Epoch 75/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4066 - acc: 0.8087
# Epoch 76/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4067 - acc: 0.8101
# Epoch 77/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4065 - acc: 0.8081
# Epoch 78/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4064 - acc: 0.8091
# Epoch 79/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4065 - acc: 0.8079
# Epoch 80/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4063 - acc: 0.8081
# Epoch 81/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4062 - acc: 0.8098
# Epoch 82/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4063 - acc: 0.8096
# Epoch 83/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4062 - acc: 0.8081
# Epoch 84/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4062 - acc: 0.8088
# Epoch 85/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4061 - acc: 0.8093
# Epoch 86/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4061 - acc: 0.8088
# Epoch 87/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4060 - acc: 0.8096
# Epoch 88/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4059 - acc: 0.8104
# Epoch 89/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4062 - acc: 0.8096
# Epoch 90/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4056 - acc: 0.8099
# Epoch 91/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4061 - acc: 0.8078
# Epoch 92/100
# 12545/12545 [==============================] - 0s 18us/step - loss: 0.4057 - acc: 0.8103
# Epoch 93/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4060 - acc: 0.8092
# Epoch 94/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4062 - acc: 0.8091
# Epoch 95/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4056 - acc: 0.8087
# Epoch 96/100
# 12545/12545 [==============================] - 0s 20us/step - loss: 0.4055 - acc: 0.8112
# Epoch 97/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4060 - acc: 0.8103
# Epoch 98/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4057 - acc: 0.8101
# Epoch 99/100
# 12545/12545 [==============================] - 0s 23us/step - loss: 0.4057 - acc: 0.8095
# Epoch 100/100
# 12545/12545 [==============================] - 0s 19us/step - loss: 0.4055 - acc: 0.8108

# %%
class ModelWithFeaturization:

    def __init__(self, nn, featurizer):
        self.nn = nn
        self.featurizer = featurizer
        
    def predict(self, df):
        return [np.argmax(p) for p in self.nn.predict(self.featurizer.transform(df).todense())]
    
    def predict_proba(self, df):
        return self.nn.predict(self.featurizer.transform(df).todense())
    
model = ModelWithFeaturization(nn, featurizer)

# %%
score_on_train_data = accuracy_score(y_train, model.predict(train_data))
score_on_noncorrupted_test_data = accuracy_score(y_test, model.predict(test_data))
score_on_noncorrupted_target_data = accuracy_score(y_target, model.predict(target_data))

print("score on train data: ", score_on_train_data)
print("score on test data: ", score_on_noncorrupted_test_data)
print("score on target data: ", score_on_noncorrupted_target_data)
# Out:
# score on train data:  0.8092467118373854
# score on test data:  0.8112244897959183
# score on target data:  0.8017845761631612

# %% [markdown]
# ### Introduce errors (missing values) into unseen test data, record resulting class probability entropies and accuracy score as inputs for the meta regressor

# %%
def percentiles_of_probas(predictions):
    probs_class_a = np.transpose(predictions)[0]
    probs_class_b = np.transpose(predictions)[1]
    features_a = np.percentile(probs_class_a, np.arange(0,101,5))
    features_b = np.percentile(probs_class_b, np.arange(0,101,5))  
    return np.concatenate((features_a, features_b), axis=0) 

num_features = 42

# %%
import random
from scipy.stats import entropy
from tqdm import tqdm

def delete_cells(df, fraction, columns):
    # we operate on a copy of the data
    corrupted_df = df.copy(deep=True)
    
    row_indexes = [row for row in range(corrupted_df.shape[0])]
    # pick random examples
    num_rows_to_pick = int(round(fraction * len(row_indexes)))
    for random_row_index in random.sample(row_indexes, num_rows_to_pick):           
        # delete all specified values in the target columns
        for column in columns:
            column_index = df.columns.get_loc(column)
            corrupted_df.iat[random_row_index, column_index] = 'n/a'
    
    return corrupted_df

generated_training_data = []

for num_columns_affected in tqdm(range(1, 5)):
    for fraction_of_values_to_delete in [0.0, 0.05, 0.25, 0.5, 0.75, 0.99]:    
        for _ in range(0, 100):        
            columns_affected = np.random.choice(categorical_columns, num_columns_affected)        

            corrupted_test_data = delete_cells(test_data, fraction_of_values_to_delete, columns_affected)

            predictions = model.predict_proba(corrupted_test_data)                     
            features = percentiles_of_probas(predictions)
                                       
            score_on_corrupted_test_data = accuracy_score(y_test, model.predict(corrupted_test_data))                
                
            example = np.concatenate((features, [score_on_corrupted_test_data]), axis=0)                                       
            
            generated_training_data.append(example)
# Out:
# 100%|██████████| 4/4 [01:35<00:00, 23.81s/it]

# %% [markdown]
# ### Fit a regression model to the generated training data

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor

X = np.array(generated_training_data)[:,:num_features]
y = np.array(generated_training_data)[:,num_features]

param_grid = {
    'learner__n_estimators': np.arange(5,20,5),
    'learner__criterion': ['mae']
}

meta_regressor_pipeline = Pipeline([
    ('scaling', StandardScaler()), 
    ('learner', RandomForestRegressor())
])

meta_regressor = GridSearchCV(meta_regressor_pipeline, param_grid, scoring='neg_mean_absolute_error').fit(X, y)

# %% [markdown]
# ### Evaluate regression model in predicting effects of errors in the unseen target data

# %%
predicted_scores = []
true_scores = []

for num_columns_affected in tqdm(range(1, 5)):
    for fraction_of_values_to_delete in [0.05, 0.25, 0.5, 0.75, 0.99]:    
        for _ in range(0, 100):        
            columns_affected = np.random.choice(categorical_columns, num_columns_affected)        

            corrupted_target_data = delete_cells(target_data, fraction_of_values_to_delete, columns_affected)

            predictions = model.predict_proba(corrupted_target_data)
            features = percentiles_of_probas(predictions)                

            score_on_corrupted_target_data = accuracy_score(y_target, model.predict(corrupted_target_data))
            predicted_score_on_corrupted_target_data = meta_regressor.predict([features])
            
            predicted_scores.append(predicted_score_on_corrupted_target_data)
            true_scores.append(score_on_corrupted_target_data)
# Out:
# 100%|██████████| 4/4 [01:23<00:00, 20.98s/it]

# %%
from scipy import stats

gradient, intercept, _, _, _ = stats.linregress(np.array(true_scores).flatten(), np.array(predicted_scores).flatten())

plt.scatter(true_scores, predicted_scores, alpha=0.05)

x1 = np.linspace(0.5, 0.8, 100)
plt.plot(x1, gradient * x1 + intercept, '-')

plt.xlabel("true accuracy on corrupted target data")
plt.ylabel("predicted accuracy on corrupted target data")
plt.plot([0.5, 0.8], [0.5, 0.8], color='black', alpha=0.5)
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mse = mean_squared_error(true_scores, predicted_scores)
mae = mean_absolute_error(true_scores, predicted_scores)

print("MSE:", mse, ", MAE:", mae)
# Out:
# MSE: 8.65905787134955e-05 , MAE: 0.007468320724561338
